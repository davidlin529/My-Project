# %% [markdown]
# ### The updated product of VAPr formatting.py
# - Created after ATAC-seq
# - Compatible with Python 2 and 3 (by using a copy library)
# - Processes large inputs by breaking it into batches

# %% [markdown]
# ## Import libraries

# %%
from VAPr import vapr_core
import os
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
IN_PATH = "."
OUT_PATH = "./results"
ANNOVAR_PATH = "/shared/workspace/software/annovar"
MONGODB = 'VariantDatabase'
COLLECTION = 'Cancer'

# %%
annotator = vapr_core.VaprAnnotator(input_dir=IN_PATH,
                                    output_dir=OUT_PATH,
                                    mongo_db_name=MONGODB,
                                    mongo_collection_name=COLLECTION,
                                    build_ver='hg19',
                                    vcfs_gzipped=False,
                                    annovar_install_path=ANNOVAR_PATH)

# %% [markdown]
# ## Download Annovar Databases

# %%
annotator.download_annovar_databases()

# %% [markdown]
# ## Drop MongoDB Collections

# %%
c = MongoClient()
c.test_database
db = c['VariantDatabase']
db.list_collection_names()
# Out:
# [u'Cancer']

# %%
db.drop_collection('Cancer')
# Out:
# {u'nIndexesWas': 1, u'ns': u'VariantDatabase.Cancer', u'ok': 1.0}

# %% [markdown]
# ## Run Annovar and MyVariant.info queries, upload variant annotations to MongoDB

# %%
dataset = annotator.annotate(num_processes=8)
# Out:
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
#   0%|          | 0/8 [00:00<?, ?it/s]/shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# /shared/workspace/software/anaconda3/envs/py27/lib/python2.7/site-packages/VAPr/vcf_genotype_fields_parsing.py:22: UserWarning: The GT tag value 0 does not split into exactly two values so genotype information could not be captured for the current variant.
#   warnings.warn(warn_msg)
# 100%|██████████| 8/8 [00:19<00:00,  2.39s/it]

# %% [markdown]
# ## Skip Annovar step, export only MyVariant data to MongoDB

# %%
dataset_light = annotator.annotate_lite(num_processes=8)

# %% [markdown]
# ## Query Rare Deleterious Variants

# %%
dataset = vapr_core.VaprDataset(MONGODB, COLLECTION)

# %%
rare_deleterious_variants = dataset.get_rare_deleterious_variants()
rare_deleterious_variants[14]
# Out:
# {u'1000g2015aug_all': 0.00838658,
#  u'_id': ObjectId('5c06f3572c788e6b1668bf12'),
#  u'alt': u'A',
#  u'cadd': {u'1000g': {u'af': 0.01, u'afr': 0.01, u'amr': 0.01, u'eur': 0.03},
#   u'_license': u'http://goo.gl/bkpNhq',
#   u'esp': {u'af': 0.015, u'afr': 0.005, u'eur': 0.02},
#   u'gerp': {u'n': 5.45, u'rs': 613.1, u'rs_pval': 7.78414e-78, u's': 5.45},
#   u'phred': 23.1,
#   u'polyphen': {u'cat': u'benign', u'val': 0.031},
#   u'sift': {u'cat': u'tolerated', u'val': 0.4}},
#  u'chr': u'14',
#  u'dbsnp': {u'_license': u'https://goo.gl/Ztr5rl', u'rsid': u'rs77202343'},
#  u'end': 24803710,
#  u'exonicfunc_knowngene': u'nonsynonymous SNV',
#  u'func_knowngene': u'exonic',
#  u'gene_knowngene': u'ADCY4',
#  u'hgvs_id': u'chr14:g.24803710G>A',
#  u'ref': u'G',
#  u'samples': [{u'AD': [292, 0],
#    u'filter_passing_reads_count': 292,
#    u'genotype': None,
#    u'sample_id': u'N7_vs_T7'}],
#  u'start': 24803710,
#  u'wellderly': {u'_license': u'https://goo.gl/e8OO17',
#   u'alleles': [{u'allele': u'A', u'freq': 0.025},
#    {u'allele': u'G', u'freq': 0.975}]}}

# %% [markdown]
# ### Filter #1: Rare deleterious variants

# %%
# Apply filter.
rare_deleterious_variants = dataset.get_rare_deleterious_variants()
len(rare_deleterious_variants)
# Out:
# 15

# %% [markdown]
# ### Filter #2: Known disease variants

# %%
# Apply filter.
known_disease_variants = dataset.get_known_disease_variants()

# %%
len(known_disease_variants)
# Out:
# 80

# %% [markdown]
# ### Filter #3: Deleterious compound heterozygous variants

# %%
# Apply filter
deleterious_compound_heterozygous = dataset.get_deleterious_compound_heterozygous_variants()

# %%
len(deleterious_compound_heterozygous)
# Out:
# 0

# %% [markdown]
# ### Filter #4: De novo variants

# %%
# Apply filter.
denovo_variants = dataset.get_de_novo_variants(proband="NA12878",
                                               ancestor1="NA12891",
                                               ancestor2="NA12892")
denovo_variants[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-026634b531c1> in <module>()
#       3                                                ancestor1="NA12891",
#       4                                                ancestor2="NA12892")
# ----> 5 denovo_variants[0]
#
# IndexError: list index out of range

# %% [markdown]
# ## Output Files

# %% [markdown]
# ## Streamlined pipeline

# %% [markdown]
# ### Extract samples

# %%
# Take each sample out from the sample column and append it in its individual row
def extract_samples(dataset_list_in):
    dataset_list_out = []  # output list

    # for every row 
    for x in range(len(dataset_list_in)):
        temp_sample_list = copy.deepcopy(dataset_list_in[x]['samples'])  # temp copy of samples list

        # for every sample in samples list
        for y in range(len(temp_sample_list)):
            temp_row_dict = copy.deepcopy(dataset_list_in[x])  # copy over the entire original row
            temp_row_dict['samples'] = copy.deepcopy(temp_sample_list[y])  # over-write with an individual sample
            dataset_list_out.append(temp_row_dict)  # add the new dict to output list

    return dataset_list_out

# %% [markdown]
# ### Unnest dictionaries

# %%
# Call unnest_dict_core and re-assemble dictionaries
def unnest_dict(dataset_list_in):
    dataset_list_out = []
    for x in range(len(dataset_list_in)):
        temp_dict = {}
        temp_dict = unnest_dict_core(dataset_list_in[x], "", True, temp_dict)
        dataset_list_out.append(temp_dict)
    return dataset_list_out


# unnest dictionaries recursively
def unnest_dict_core(nested_dict_in, prev_key, first_level, unnested_dict_out):
    keys = list(nested_dict_in.keys())  # a list of keys

    for key in keys:

        # set key names
        if first_level:
            key_name = str(key)
        else:
            key_name = prev_key + "." + str(key)

        # check type
        if type(nested_dict_in[str(key)]) == dict:
            unnest_dict_core(nested_dict_in[str(key)], key_name, False, unnested_dict_out)
        else:
            unnested_dict_out[key_name] = nested_dict_in[str(key)]
    return unnested_dict_out

# %% [markdown]
# ### Unnest list

# %%
# A wrapper that unnnest lists by calling find_list
def unnest_list(dataset_list_in):
    dataset_list_out = copy.deepcopy(dataset_list_in)  # make a copy for output

    # for every row
    for x in range(len(dataset_list_in)):
        # print(x)
        dataset_list_out[x] = find_list(dataset_list_in[x])  # find any key whose value is a list

    return dataset_list_out


# Finds field that are dictionaries. Find column in the table that contain a list whose keys that would be identical
# when unnested and calls rename list. Look for key whose value is a list, call rename_list_content.
def find_list(dict_in):
    dict_out = copy.deepcopy(dict_in)  # make a copy of the row
    dict_keys = list(dict_in.keys())  # a list of keys

    # for every key in that row
    for dict_key in dict_keys:

        # find fields that are lists
        if type(dict_in[dict_key]) == list:
            # print(dict_key + " is a list")

            has_dict = True  # contains dictionaries

            # check if the list contains dictionaries
            for key_values in dict_in[dict_key]:
                if type(key_values) != dict:
                    has_dict = False

            # proceed when the list contains dictionaries
            if has_dict:
                # print(dict_key + " contains dictionaries")
                dict_out[dict_key] = rename_list_content(dict_in[dict_key])  # rename list content

    return dict_out


# Since the keys can have the same names in the dictionary, this function renames the items by appending a number at
# the end of each item. Having keys with the same name in a dictionary throws an error.
# rename dictionaries in the list such that they can be unnested in the same level and and keys can be unique.
def rename_list_content(same_keys_list):
    new_keys_dict_out = {}  # output

    # for every dictionary in the list
    for x in range(len(same_keys_list)):
        old_keys = list(same_keys_list[x].keys())  # original keys
        new_keys = copy.deepcopy(old_keys)  # keys to be modified

        # for every key
        for y in range(len(new_keys)):
            new_keys[y] += str(x + 1)  # modify the key with index

            # add the modified key and its value to a new dict
            new_keys_dict_out[str(new_keys[y])] = same_keys_list[x][old_keys[y]]

    return new_keys_dict_out

# %% [markdown]
# ### Change 'samples.AD' to 't_ref_count' and 't_alt_count'

# %%
# Call change_name to change 'samples.AD' to 't_ref_count' and 't_alt_count', because they are required fields in MAf. 
def samples_AD(dataset_list_in):
    dataset_list_out = []  # output list

    # for every row
    for x in range(len(dataset_list_in)):
        dataset_list_out.append(change_name(dataset_list_in[x]))
    return dataset_list_out

# Change 'samples.AD' to 't_ref_count' and 't_alt_count'
def change_name(sample_dict_in):
    sample_dict_out = {}  # output dict
    keys = list(sample_dict_in.keys())
    for key in keys:

        # change 'samples.AD'
        if key == 'samples.AD':
            sample_dict_out['t_ref_count'] = sample_dict_in['samples.AD'][0]
            sample_dict_out['t_alt_count'] = sample_dict_in['samples.AD'][1]
        else:
            sample_dict_out[key] = sample_dict_in[key]  # copy over other fields
    return sample_dict_out

# %% [markdown]
# ### Record Variant_Type

# %%
# Record variant type according to ref and alt alleles. Determines the variant type based on the 
# number of ref and alt alleles
def varType(dataset_list_in):
    for x in range(len(dataset_list_in)):
        ref = len(dataset_list_in[x]['ref'])
        alt = len(dataset_list_in[x]['alt'])
        if ref == alt == 1:
            dataset_list_in[x]['Variant_Type'] = 'SNP'
        if ref == alt == 2:
            dataset_list_in[x]['Variant_Type'] = 'DNP'
        if ref == alt == 3:
            dataset_list_in[x]['Variant_Type'] = 'TNP'
        if ref == alt and ref > 3:
            dataset_list_in[x]['Variant_Type'] = 'ONP'
        if ref < alt:
            dataset_list_in[x]['Variant_Type'] = 'INS'
        if ref > alt:
            dataset_list_in[x]['Variant_Type'] = 'DEL'

    return dataset_list_in

# %% [markdown]
# ### Unnest multiple values separated by ";" in a single field

# %%
# Fields with multiple values to separate: gene_knowngene, genedetail_knowngene, func_knowngene
# Takes in the whole table. Find fields with multiple values and attemp to separates those values and put each in a 
# new row. 
def unnest_semicolon_values(data_list_in):
    debug_genes = False
    debug_genes_and_func = False
    debug_genes_and_genedetails = False
    debug_genes_and_func_and_genedetails = False
    debug_lengths_check = False
    multiple_values_count = 0  # testing use

    data_list_out = []  # the output table to be returned

    # for every row in the whole table
    for row in data_list_in:
        if row['gene_knowngene'].find(';') is not -1:

            # testing use
            if debug_genes:
                print(row['gene_knowngene'])

            temp_rows_list = []  # holds row copies temporarily
            gene_knowngene_values = row['gene_knowngene'].split(';')

            # for every gene after splitting
            for gene in gene_knowngene_values:
                temp_row_dict = copy.deepcopy(row)  # copy the whole row
                temp_row_dict['gene_knowngene'] = gene  # replace with individual gene
                temp_rows_list.append(temp_row_dict)  # put rows in a list temporarily

            func_knowngene_values = row['func_knowngene'].split(';')

            # Match genes with corresponding funcs only when there are the same numbers of them
            # In the case of multiple genes with only 1 func, that 1 func is copied over to a new row 
            #    with every gene, so that case is always taken care of. 
            if len(func_knowngene_values) == len(gene_knowngene_values):
                # for every new row created after splitting genes
                for index in range(len(temp_rows_list)):
                    temp_rows_list[index]['func_knowngene'] = func_knowngene_values[
                        index]  # replace with individual func

                # testing use
                if debug_genes_and_func:
                    print(row['gene_knowngene'])
                    print(row['func_knowngene'] + "\n")
                    for x in temp_rows_list:
                        print(x['gene_knowngene'] + "  " + x['func_knowngene'])
                    print('\n')

            if 'genedetail_knowngene' in row.keys():
                genedetail_knowngene_values = row['genedetail_knowngene'].split(';')

                # Match genes with corresponding genedetails only when there are the same numbers of them
                # In the case of multiple genes with only 1 genedetail, that 1 genedetail is copied over to a new row 
                #    with every gene, so that case is always taken care of. 
                if len(genedetail_knowngene_values) == len(gene_knowngene_values):

                    # for every new row created after splitting genes
                    for index in range(len(temp_rows_list)):
                        temp_rows_list[index]['genedetail_knowngene'] = genedetail_knowngene_values[index]

                    # testing use
                    if debug_genes_and_genedetails:
                        print(row['gene_knowngene'])
                        print(row['func_knowngene'])
                        print(row['genedetail_knowngene'] + "\n")
                        for x in temp_rows_list:
                            print(x['gene_knowngene'] + "  " + x['func_knowngene'] + "  " + x['genedetail_knowngene'])
                        print('\n')

                    # testing use
                    if debug_genes_and_func_and_genedetails:
                        if len(genedetail_knowngene_values) == len(gene_knowngene_values) == len(func_knowngene_values):
                            print(row['gene_knowngene'])
                            print(row['func_knowngene'])
                            print(row['genedetail_knowngene'] + "\n")
                            for x in temp_rows_list:
                                print(
                                x['gene_knowngene'] + "  " + x['func_knowngene'] + "  " + x['genedetail_knowngene'])
                            print('\n')

            # testing use
            if debug_genes:
                for x in temp_rows_list:
                    print(x['gene_knowngene'] + "  " + x['func_knowngene'])

            # write the newly created rows to the output table
            for temp_row in temp_rows_list:
                data_list_out.append(temp_row)

                # testing use
                if debug_lengths_check:
                    multiple_values_count += 1

            # testing use
            if debug_lengths_check:
                multiple_values_count -= 1

        # write the row to the output table as it is
        else:
            data_list_out.append(copy.deepcopy(row))

    # testing use
    if debug_lengths_check:
        print("The lenght of data input: " + str(len(data_list_in)))
        print("The lenght of data output: " + str(len(data_list_out)))
        print("The difference in lengths: " + str(multiple_values_count))
        print("New rows created: " + str(len(data_list_in) - len(data_list_out)))

    return data_list_out

# %% [markdown]
# ### Re-arrange and rename columns

# %%
# Re-arrange and rename columns to match the MAF format
def change_cols(df):
    cols = list(df)
    cols.insert(0, cols.pop(cols.index('gene_knowngene')))
    cols.insert(1, cols.pop(cols.index('chr')))
    cols.insert(2, cols.pop(cols.index('start')))
    cols.insert(3, cols.pop(cols.index('end')))
    cols.insert(4, cols.pop(cols.index('ref')))
    cols.insert(5, cols.pop(cols.index('alt')))
    cols.insert(6, cols.pop(cols.index('Variant_Type')))
    cols.insert(7, cols.pop(cols.index('func_knowngene')))
    cols.insert(8, cols.pop(cols.index('samples.sample_id')))
    cols.insert(9, cols.pop(cols.index('dbsnp.rsid')))
    cols.insert(10, cols.pop(cols.index('t_ref_count')))
    cols.insert(11, cols.pop(cols.index('t_alt_count')))
    # cols.insert(12, cols.pop(cols.index('aachange_knowngene')))

    df = df.loc[:, cols]

    df = df.rename(columns={'gene_knowngene': 'Hugo_Symbol',
                            'chr': 'Chromosome',
                            'start': 'Start_Position',
                            'end': 'End_Position',
                            'ref': 'Reference_Allele',
                            'alt': 'Tumor_Seq_Allele2',
                            'func_knowngene': 'Variant_Classification',
                            'samples.sample_id': 'Tumor_Sample_Barcode',
                            'cadd.1000g.afr': 'AFR_MAF',
                            'cadd.1000g.amr': 'AMR_MAF',
                            'cadd.1000g.asn': 'ASN_MAF',
                            'cadd.1000g.eur': 'EUR_MAF',
                            'dbsnp.rsid': 'dbSNP_RS'
                            # 'aachange_knowngene': 'Protein_Change'
                            })

    df['Variant_Classification'] = df['Variant_Classification'].replace({
        'intronic': 'Intron',
        'intergenic': 'IGR',
        'UTR3': "3'UTR",
        "UTR5": "5'UTR",
        'downstream': "3'Flank",
        'upstream': "5'Flank",
        'splicing': 'Splice_Site', 'ncRNA_exonic': 'RNA',
        'ncRNA_intronic': 'RNA', 'ncRNA_UTR3': 'RNA',
        'ncRNA_UTR5': 'RNA', 'ncRNA': 'RNA', })

    mask = df.exonicfunc_knowngene == 'nonsynonymous SNV'
    df.loc[mask, 'Variant_Classification'] = "Missense_Mutation"
    mask = df.exonicfunc_knowngene == 'synonymous SNV'
    df.loc[mask, 'Variant_Classification'] = "Silent"
    mask = df.exonicfunc_knowngene == 'stopgain'
    df.loc[mask, 'Variant_Classification'] = "Nonsense_Mutation"
    mask = df.exonicfunc_knowngene == 'stoploss'
    df.loc[mask, 'Variant_Classification'] = "Nonstop_Mutation"
    mask = df.exonicfunc_knowngene == 'frameshift insertion'
    df.loc[mask, 'Variant_Classification'] = "Frame_Shift_Ins"
    mask = df.exonicfunc_knowngene == 'frameshift deletion'
    df.loc[mask, 'Variant_Classification'] = "Frame_Shift_Del"
    mask = df.exonicfunc_knowngene == 'nonframeshift insertion'
    df.loc[mask, 'Variant_Classification'] = "In_Frame_Ins"
    mask = df.exonicfunc_knowngene == 'nonframeshift deletion'
    df.loc[mask, 'Variant_Classification'] = "In_Frame_Del"

    return df

# %% [markdown]
# ### Maf formatter wrapper function

# %%
# Formats the output from VAPr such that the output matches MAF format, allowing for downstream processing and 
# analysis in Maftools A wrapper for the functions above
# Input: a VAPr output list
# Output: a formatted data frame ready to be saved as a MAF file
def maf_formatter(dataset_list_in):
    import pandas as pd
    import copy

    debug = False
    dataset_list_out = []  # the formatted list
    if debug == True:
        print(len(dataset_list_in))
    
    interval = 5   # the size of each subset of the input
    left_ptr = 0   # the left pointer of the subset
    right_ptr = left_ptr + interval  # the right pointer of the subset
    
    # Subsets the input iteratively, calls maf_formatter_core to format each subset, and then appends each 
    # subset to the formatted list for output
    while left_ptr < len(dataset_list_in):
        unformatted_subset_list = dataset_list_in[left_ptr:right_ptr]  # subsets the list
        
        if debug == True:
            print("Length of fragment: " + str(len(unformatted_subset_list)))
        
        formatted_subset_list = maf_formatter_core(unformatted_subset_list) # formats the subset
        
        # appends the items in the subset to the formatted list for output
        for item in formatted_subset_list:
            dataset_list_out.append(item)
            
        if debug == True:
            print("Output list current length: " + str(len(output_list)))
        
        # increment the pointers for the next subset
        left_ptr += interval
        right_ptr += interval
        
    if debug == True:
        print(len(dataset_list_out))

    df = pd.DataFrame(data=dataset_list_out)
    df2 = change_cols(df)

    return df2

def maf_formatter_core(dataset_list_in):
    k0 = copy.deepcopy(dataset_list_in)
    k1 = extract_samples(k0)
    k2 = unnest_dict(k1)
    k3 = unnest_list(k2)
    k4 = unnest_dict(k3)
    k5 = samples_AD(k4)
    k6 = varType(k5)
    k7 = unnest_semicolon_values(k6)
    
    return k7

# %% [markdown]
# ### Main

# %%
myDf = maf_formatter(known_disease_variants)
myDf
# Out:
#     Hugo_Symbol Chromosome  Start_Position  End_Position Reference_Allele  \
# 0         PTCH1          9        98231215      98231215                C
# 1       PPP1R26          9       138376649     138376649                T
# 2        NOTCH1          9       139396889     139396889                G
# 3        NOTCH1          9       139412607     139412607                C
# 4        NOTCH1          9       139413084     139413084                C
# 5       AKAP17A          X         1719897       1719897                C
# 6          ASMT          X         1755404       1755404                C
# 7          HRAS         11          534285        534285                C
# 8          HRAS         11          534285        534285                C
# 9          HRAS         11          534285        534285                C
# 10         HRAS         11          534285        534285                C
# 11         MUC6         11         1016919       1016919                C
# 12        MAML2         11        95825407      95825407                C
# 13        MAML2         11        95825407      95825407                C
# 14          ATM         11       108236786     108236786                T
# 15         NONE         MT            3796          3796                A
# 16         NONE         MT            3796          3796                A
# 17         NONE         MT           10197         10197                G
# 18         NONE         MT           10197         10197                G
# 19         NONE         MT           14160         14160                G
# 20         NONE         MT           14160         14160                G
# 21         NONE         MT           15003         15003                G
# 22         NONE         MT           15003         15003                G
# 23        FBXW7          4       153245446     153245446                G
# 24        FBXW7          4       153247289     153247289                G
# 25        FBXW7          4       153247289     153247289                G
# 26        FBXW7          4       153247289     153247289                G
# 27        FBXW7          4       153247289     153247289                G
# 28        FBXW7          4       153247366     153247366                C
# 29        FBXW7          4       153249384     153249384                C
# ..          ...        ...             ...           ...              ...
# 85       PIK3CA          3       178936091     178936091                G
# 86       PIK3CA          3       178936091     178936091                G
# 87       PIK3CA          3       178936091     178936091                G
# 88       PIK3CA          3       178936091     178936091                G
# 89       PIK3CA          3       178936091     178936091                G
# 90       PIK3CA          3       178936091     178936091                G
# 91       PIK3CA          3       178936091     178936091                G
# 92       PIK3CA          3       178936091     178936091                G
# 93       PIK3CA          3       178952090     178952090                G
# 94        FGFR3          4         1803568       1803568                C
# 95        FGFR3          4         1803568       1803568                C
# 96        FGFR3          4         1803568       1803568                C
# 97        FGFR3          4         1803568       1803568                C
# 98        FGFR3          4         1803568       1803568                C
# 99        FGFR3          4         1803568       1803568                C
# 100       FGFR3          4         1806089       1806089                G
# 101        PTEN         10        89685281      89685281                C
# 102        PTEN         10        89692905      89692905                G
# 103       KMT2D         12        49425644      49425644                G
# 104       KMT2D         12        49437153      49437153                A
# 105        KRT7         12        52635360      52635360                G
# 106       ATXN2         12       112036800     112036800                C
# 107       ATXN2         12       112036800     112036800                C
# 108       ATXN2         12       112036800     112036800                C
# 109       ATXN2         12       112036800     112036800                C
# 110       NCOR2         12       124887096     124887096                T
# 111       NCOR2         12       124887096     124887096                T
# 112         B2M         15        45003746      45003746                T
# 113      CREBBP         16         3781375       3781375                G
# 114      CREBBP         16         3788618       3788618                G
#
#     Tumor_Seq_Allele2 Variant_Type Variant_Classification  \
# 0                   T          SNP      Missense_Mutation
# 1                   C          SNP      Missense_Mutation
# 2                   A          SNP      Missense_Mutation
# 3                   T          SNP      Missense_Mutation
# 4                   T          SNP      Missense_Mutation
# 5                   G          SNP      Missense_Mutation
# 6                   T          SNP                 Silent
# 7                   A          SNP      Missense_Mutation
# 8                   A          SNP      Missense_Mutation
# 9                   T          SNP      Missense_Mutation
# 10                  T          SNP      Missense_Mutation
# 11                  T          SNP      Missense_Mutation
# 12                  T          SNP                 Silent
# 13                  T          SNP                 Silent
# 14                  C          SNP                  3'UTR
# 15                  G          SNP                    IGR
# 16                  G          SNP                    IGR
# 17                  A          SNP                    IGR
# 18                  A          SNP                    IGR
# 19                  A          SNP                    IGR
# 20                  A          SNP                    IGR
# 21                  A          SNP                    IGR
# 22                  A          SNP                    IGR
# 23                  A          SNP      Missense_Mutation
# 24                  A          SNP      Missense_Mutation
# 25                  A          SNP      Missense_Mutation
# 26                  C          SNP      Missense_Mutation
# 27                  C          SNP      Missense_Mutation
# 28                  T          SNP      Missense_Mutation
# 29                  T          SNP      Missense_Mutation
# ..                ...          ...                    ...
# 85                  A          SNP      Missense_Mutation
# 86                  A          SNP      Missense_Mutation
# 87                  A          SNP      Missense_Mutation
# 88                  A          SNP      Missense_Mutation
# 89                  A          SNP      Missense_Mutation
# 90                  A          SNP      Missense_Mutation
# 91                  A          SNP      Missense_Mutation
# 92                  A          SNP      Missense_Mutation
# 93                  C          SNP      Missense_Mutation
# 94                  G          SNP      Missense_Mutation
# 95                  G          SNP      Missense_Mutation
# 96                  G          SNP      Missense_Mutation
# 97                  G          SNP      Missense_Mutation
# 98                  G          SNP      Missense_Mutation
# 99                  G          SNP      Missense_Mutation
# 100                 T          SNP      Missense_Mutation
# 101                 G          SNP      Nonsense_Mutation
# 102                 A          SNP      Missense_Mutation
# 103                 A          SNP      Nonsense_Mutation
# 104                 G          SNP                 Silent
# 105                 A          SNP                 Silent
# 106                 T          SNP                 Silent
# 107                 T          SNP                 Silent
# 108                 T          SNP                 Silent
# 109                 T          SNP                 Silent
# 110                 C          SNP                 Silent
# 111                 C          SNP                 Silent
# 112                 A          SNP      Missense_Mutation
# 113                 A          SNP      Missense_Mutation
# 114                 A          SNP      Missense_Mutation
#
#     Tumor_Sample_Barcode      dbSNP_RS           ...            \
# 0             N40_vs_T40   rs750970743           ...
# 1             N39_vs_T39     rs3748192           ...
# 2             N44_vs_T44   rs777962754           ...
# 3             N39_vs_T39   rs373770404           ...
# 4             N44_vs_T44   rs750215904           ...
# 5             N39_vs_T39    rs28661622           ...
# 6               N7_vs_T7     rs4933063           ...
# 7               N1_vs_T1   rs104894226           ...
# 8             N17_vs_T17   rs104894226           ...
# 9               N1_vs_T1   rs104894226           ...
# 10            N17_vs_T17   rs104894226           ...
# 11            N36_vs_T36   rs536595477           ...
# 12              N9_vs_T9    rs61901862           ...
# 13            N39_vs_T39    rs61901862           ...
# 14              N7_vs_T7   rs143531724           ...
# 15            N39_vs_T39    rs28357970           ...
# 16            N39_vs_T39    rs28357970           ...
# 17            N32_vs_T32   rs267606891           ...
# 18            N32_vs_T32   rs267606891           ...
# 19            N39_vs_T39           NaN           ...
# 20            N39_vs_T39           NaN           ...
# 21            N43_vs_T43           NaN           ...
# 22            N43_vs_T43           NaN           ...
# 23            N47_vs_T47           NaN           ...
# 24              N2_vs_T2   rs149680468           ...
# 25            N30_vs_T30   rs149680468           ...
# 26              N2_vs_T2   rs149680468           ...
# 27            N30_vs_T30   rs149680468           ...
# 28              N4_vs_T4   rs866987936           ...
# 29            N45_vs_T45  rs1057519895           ...
# ..                   ...           ...           ...
# 85            N14_vs_T14   rs104886003           ...
# 86            N12_vs_T12   rs104886003           ...
# 87              N2_vs_T2   rs104886003           ...
# 88            N31_vs_T31   rs104886003           ...
# 89              N1_vs_T1   rs104886003           ...
# 90            N36_vs_T36   rs104886003           ...
# 91            N41_vs_T41   rs104886003           ...
# 92            N30_vs_T30   rs104886003           ...
# 93            N38_vs_T38   rs121913277           ...
# 94            N10_vs_T10   rs121913483           ...
# 95            N28_vs_T28   rs121913483           ...
# 96              N4_vs_T4   rs121913483           ...
# 97            N38_vs_T38   rs121913483           ...
# 98              N6_vs_T6   rs121913483           ...
# 99            N41_vs_T41   rs121913483           ...
# 100           N44_vs_T44   rs121913479           ...
# 101           N10_vs_T10  rs1060500116           ...
# 102           N16_vs_T16   rs121909229           ...
# 103           N17_vs_T17  rs1057517992           ...
# 104             N7_vs_T7   rs137955659           ...
# 105             N7_vs_T7      rs999665           ...
# 106           N45_vs_T45   rs750715026           ...
# 107           N25_vs_T25   rs750715026           ...
# 108             N7_vs_T7   rs750715026           ...
# 109           N16_vs_T16   rs750715026           ...
# 110           N46_vs_T46     rs3040832           ...
# 111           N16_vs_T16     rs3040832           ...
# 112           N39_vs_T39           NaN           ...
# 113           N18_vs_T18           NaN           ...
# 114             N3_vs_T3   rs398124146           ...
#
#      exonicfunc_knowngene                               genedetail_knowngene  \
# 0       nonsynonymous SNV                                                NaN
# 1       nonsynonymous SNV                                                NaN
# 2       nonsynonymous SNV                                                NaN
# 3       nonsynonymous SNV                                                NaN
# 4       nonsynonymous SNV                                                NaN
# 5       nonsynonymous SNV                                                NaN
# 6          synonymous SNV                                                NaN
# 7       nonsynonymous SNV                                                NaN
# 8       nonsynonymous SNV                                                NaN
# 9       nonsynonymous SNV                                                NaN
# 10      nonsynonymous SNV                                                NaN
# 11      nonsynonymous SNV                                                NaN
# 12         synonymous SNV                                                NaN
# 13         synonymous SNV                                                NaN
# 14                    NaN  uc001pkb.1:c.*551T>C;uc009yxr.1:c.*551T>C;uc00...
# 15                    NaN                                          dist=NONE
# 16                    NaN                                          dist=NONE
# 17                    NaN                                          dist=NONE
# 18                    NaN                                          dist=NONE
# 19                    NaN                                          dist=NONE
# 20                    NaN                                          dist=NONE
# 21                    NaN                                          dist=NONE
# 22                    NaN                                          dist=NONE
# 23      nonsynonymous SNV                                                NaN
# 24      nonsynonymous SNV                                                NaN
# 25      nonsynonymous SNV                                                NaN
# 26      nonsynonymous SNV                                                NaN
# 27      nonsynonymous SNV                                                NaN
# 28      nonsynonymous SNV                                                NaN
# 29      nonsynonymous SNV                                                NaN
# ..                    ...                                                ...
# 85      nonsynonymous SNV                                                NaN
# 86      nonsynonymous SNV                                                NaN
# 87      nonsynonymous SNV                                                NaN
# 88      nonsynonymous SNV                                                NaN
# 89      nonsynonymous SNV                                                NaN
# 90      nonsynonymous SNV                                                NaN
# 91      nonsynonymous SNV                                                NaN
# 92      nonsynonymous SNV                                                NaN
# 93      nonsynonymous SNV                                                NaN
# 94      nonsynonymous SNV                                                NaN
# 95      nonsynonymous SNV                                                NaN
# 96      nonsynonymous SNV                                                NaN
# 97      nonsynonymous SNV                                                NaN
# 98      nonsynonymous SNV                                                NaN
# 99      nonsynonymous SNV                                                NaN
# 100     nonsynonymous SNV                                                NaN
# 101              stopgain                                                NaN
# 102     nonsynonymous SNV                                                NaN
# 103              stopgain                                                NaN
# 104        synonymous SNV                                                NaN
# 105        synonymous SNV                                                NaN
# 106        synonymous SNV                                                NaN
# 107        synonymous SNV                                                NaN
# 108        synonymous SNV                                                NaN
# 109        synonymous SNV                                                NaN
# 110        synonymous SNV                                                NaN
# 111        synonymous SNV                                                NaN
# 112     nonsynonymous SNV                                                NaN
# 113     nonsynonymous SNV                                                NaN
# 114     nonsynonymous SNV                                                NaN
#
#                   hgvs_id samples.filter_passing_reads_count  \
# 0      chr9:g.98231215C>T                                263
# 1     chr9:g.138376649T>C                                 88
# 2     chr9:g.139396889G>A                                102
# 3     chr9:g.139412607C>T                                 71
# 4     chr9:g.139413084C>T                                106
# 5       chrX:g.1719897C>G                                118
# 6       chrX:g.1755404C>T                                542
# 7       chr11:g.534285C>A                                136
# 8       chr11:g.534285C>A                                146
# 9       chr11:g.534285C>T                                136
# 10      chr11:g.534285C>T                                146
# 11     chr11:g.1016919C>T                                 10
# 12    chr11:g.95825407C>T                                381
# 13    chr11:g.95825407C>T                                242
# 14   chr11:g.108236786T>C                                 87
# 15        chrMT:g.3796A>G                                 27
# 16        chrMT:g.3796A>G                                 27
# 17       chrMT:g.10197G>A                                 11
# 18       chrMT:g.10197G>A                                 11
# 19       chrMT:g.14160G>A                                 29
# 20       chrMT:g.14160G>A                                 29
# 21       chrMT:g.15003G>A                                 13
# 22       chrMT:g.15003G>A                                 13
# 23    chr4:g.153245446G>A                                421
# 24    chr4:g.153247289G>A                                306
# 25    chr4:g.153247289G>A                                391
# 26    chr4:g.153247289G>C                                306
# 27    chr4:g.153247289G>C                                391
# 28    chr4:g.153247366C>T                                439
# 29    chr4:g.153249384C>T                                326
# ..                    ...                                ...
# 85    chr3:g.178936091G>A                                290
# 86    chr3:g.178936091G>A                                232
# 87    chr3:g.178936091G>A                                173
# 88    chr3:g.178936091G>A                                314
# 89    chr3:g.178936091G>A                                186
# 90    chr3:g.178936091G>A                                145
# 91    chr3:g.178936091G>A                                268
# 92    chr3:g.178936091G>A                                209
# 93    chr3:g.178952090G>C                                481
# 94      chr4:g.1803568C>G                                 79
# 95      chr4:g.1803568C>G                                146
# 96      chr4:g.1803568C>G                                102
# 97      chr4:g.1803568C>G                                 86
# 98      chr4:g.1803568C>G                                199
# 99      chr4:g.1803568C>G                                 77
# 100     chr4:g.1806089G>T                                 90
# 101   chr10:g.89685281C>G                                257
# 102   chr10:g.89692905G>A                                348
# 103   chr12:g.49425644G>A                                 78
# 104   chr12:g.49437153A>G                                364
# 105   chr12:g.52635360G>A                                 20
# 106  chr12:g.112036800C>T                                 59
# 107  chr12:g.112036800C>T                                 45
# 108  chr12:g.112036800C>T                                 63
# 109  chr12:g.112036800C>T                                 39
# 110  chr12:g.124887096T>C                                 38
# 111  chr12:g.124887096T>C                                 45
# 112   chr15:g.45003746T>A                                128
# 113    chr16:g.3781375G>A                                 70
# 114    chr16:g.3788618G>A                                235
#
#      samples.genotype     wellderly._license  wellderly.alleles.allele1  \
# 0                None                    NaN                        NaN
# 1                None  https://goo.gl/e8OO17                          C
# 2                None                    NaN                        NaN
# 3                None                    NaN                        NaN
# 4                None                    NaN                        NaN
# 5                None  https://goo.gl/e8OO17                          C
# 6                None  https://goo.gl/e8OO17                          C
# 7                None                    NaN                        NaN
# 8                None                    NaN                        NaN
# 9                None                    NaN                        NaN
# 10               None                    NaN                        NaN
# 11               None                    NaN                        NaN
# 12               None  https://goo.gl/e8OO17                          C
# 13               None  https://goo.gl/e8OO17                          C
# 14               None  https://goo.gl/e8OO17                          C
# 15               None                    NaN                        NaN
# 16               None                    NaN                        NaN
# 17               None                    NaN                        NaN
# 18               None                    NaN                        NaN
# 19               None                    NaN                        NaN
# 20               None                    NaN                        NaN
# 21               None                    NaN                        NaN
# 22               None                    NaN                        NaN
# 23               None                    NaN                        NaN
# 24               None                    NaN                        NaN
# 25               None                    NaN                        NaN
# 26               None                    NaN                        NaN
# 27               None                    NaN                        NaN
# 28               None                    NaN                        NaN
# 29               None                    NaN                        NaN
# ..                ...                    ...                        ...
# 85               None                    NaN                        NaN
# 86               None                    NaN                        NaN
# 87               None                    NaN                        NaN
# 88               None                    NaN                        NaN
# 89               None                    NaN                        NaN
# 90               None                    NaN                        NaN
# 91               None                    NaN                        NaN
# 92               None                    NaN                        NaN
# 93               None                    NaN                        NaN
# 94               None                    NaN                        NaN
# 95               None                    NaN                        NaN
# 96               None                    NaN                        NaN
# 97               None                    NaN                        NaN
# 98               None                    NaN                        NaN
# 99               None                    NaN                        NaN
# 100              None                    NaN                        NaN
# 101              None                    NaN                        NaN
# 102              None                    NaN                        NaN
# 103              None                    NaN                        NaN
# 104              None                    NaN                        NaN
# 105              None  https://goo.gl/e8OO17                          A
# 106              None                    NaN                        NaN
# 107              None                    NaN                        NaN
# 108              None                    NaN                        NaN
# 109              None                    NaN                        NaN
# 110              None  https://goo.gl/e8OO17                          C
# 111              None  https://goo.gl/e8OO17                          C
# 112              None                    NaN                        NaN
# 113              None                    NaN                        NaN
# 114              None                    NaN                        NaN
#
#      wellderly.alleles.allele2  wellderly.alleles.freq1  \
# 0                          NaN                      NaN
# 1                            T                   0.2075
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                            G                   0.4025
# 6                            T                   0.9225
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                           T                   0.8600
# 13                           T                   0.8600
# 14                           T                   0.0275
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# 26                         NaN                      NaN
# 27                         NaN                      NaN
# 28                         NaN                      NaN
# 29                         NaN                      NaN
# ..                         ...                      ...
# 85                         NaN                      NaN
# 86                         NaN                      NaN
# 87                         NaN                      NaN
# 88                         NaN                      NaN
# 89                         NaN                      NaN
# 90                         NaN                      NaN
# 91                         NaN                      NaN
# 92                         NaN                      NaN
# 93                         NaN                      NaN
# 94                         NaN                      NaN
# 95                         NaN                      NaN
# 96                         NaN                      NaN
# 97                         NaN                      NaN
# 98                         NaN                      NaN
# 99                         NaN                      NaN
# 100                        NaN                      NaN
# 101                        NaN                      NaN
# 102                        NaN                      NaN
# 103                        NaN                      NaN
# 104                        NaN                      NaN
# 105                          G                   0.5300
# 106                        NaN                      NaN
# 107                        NaN                      NaN
# 108                        NaN                      NaN
# 109                        NaN                      NaN
# 110                          T                   0.0025
# 111                          T                   0.0025
# 112                        NaN                      NaN
# 113                        NaN                      NaN
# 114                        NaN                      NaN
#
#     wellderly.alleles.freq2
# 0                       NaN
# 1                    0.7925
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                    0.5975
# 6                    0.0775
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                   0.1400
# 13                   0.1400
# 14                   0.9725
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ..                      ...
# 85                      NaN
# 86                      NaN
# 87                      NaN
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92                      NaN
# 93                      NaN
# 94                      NaN
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                      NaN
# 100                     NaN
# 101                     NaN
# 102                     NaN
# 103                     NaN
# 104                     NaN
# 105                  0.4700
# 106                     NaN
# 107                     NaN
# 108                     NaN
# 109                     NaN
# 110                  0.9975
# 111                  0.9975
# 112                     NaN
# 113                     NaN
# 114                     NaN
#
# [115 rows x 1020 columns]

# %%
myDf.to_csv('rare_deleterious_variants.maf',  sep= "\t", index=False)

# %% [markdown]
# ## Whole data collection

# %%
col = db[COLLECTION]
col_lect = col.find({})

wholeDataSet = []
for document in col_lect:
    wholeDataSet.append(document)
print(len(wholeDataSet))
wholeDataSet[823]
# Out:
# 15630
# {u'_id': ObjectId('5c06f3542c788e6b1d68bec2'),
#  u'alt': u'G',
#  u'chr': u'Y',
#  u'end': 58983134,
#  u'func_knowngene': u'intergenic',
#  u'gene_knowngene': u'NONE;SPRY3',
#  u'genedetail_knowngene': u'dist=NONE;dist=117323',
#  u'hgvs_id': u'chrY:g.58983134A>G',
#  u'notfound': True,
#  u'ref': u'A',
#  u'samples': [{u'AD': [38, 0],
#    u'filter_passing_reads_count': 29,
#    u'genotype': None,
#    u'sample_id': u'N10_vs_T10'}],
#  u'start': 58983134}

# %%
myDf = maf_formatter(wholeDataSet)
myDf
# Out:
#       Hugo_Symbol Chromosome  Start_Position  End_Position Reference_Allele  \
# 0        BC064148          9        69512439      69512439                A
# 1        BC070322          9        69512439      69512439                A
# 2        BC064148          9        69519038      69519038                G
# 3        BC070322          9        69519038      69519038                G
# 4        BC070322          9        69649186      69649186                A
# 5        AK310876          9        69772113      69772113                C
# 6         FOXD4L5          9        69772113      69772113                C
# 7        AK310876          9        69798394      69798394                C
# 8         FOXD4L5          9        69798394      69798394                C
# 9        AK310876          9        69798414      69798414                G
# 10        FOXD4L5          9        69798414      69798414                G
# 11       AK310876          9        69807199      69807199                C
# 12        FOXD4L5          9        69807199      69807199                C
# 13       AK310876          9        69807242      69807242                C
# 14        FOXD4L5          9        69807242      69807242                C
# 15       AK310876          9        69807260      69807260                T
# 16        FOXD4L5          9        69807260      69807260                T
# 17       AK310876          9        69822476      69822476                G
# 18        FOXD4L5          9        69822476      69822476                G
# 19       AK310876          9        69888672      69888672                G
# 20        FOXD4L5          9        69888672      69888672                G
# 21       AK310876          9        69888686      69888686                A
# 22        FOXD4L5          9        69888686      69888686                A
# 23       AK310876          9        69888735      69888735                C
# 24        FOXD4L5          9        69888735      69888735                C
# 25       AK310876          9        70122471      70122471                A
# 26        FOXD4L5          9        70122471      70122471                A
# 27       AK310876          9        70123312      70123312                C
# 28        FOXD4L5          9        70123312      70123312                C
# 29        FOXD4L5          9        70179448      70179448                G
# ...           ...        ...             ...           ...              ...
# 26839    BC068290         16        33946311      33946311                G
# 26840   LINC00273         16        33946311      33946311                G
# 26841    BC068290         16        33946311      33946311                G
# 26842   LINC00273         16        33946311      33946311                G
# 26843    BC068290         16        33946311      33946311                G
# 26844   LINC00273         16        33946311      33946311                G
# 26845    BC068290         16        33946311      33946311                G
# 26846   LINC00273         16        33946311      33946311                G
# 26847    BC068290         16        33946311      33946311                G
# 26848   LINC00273         16        33946311      33946311                G
# 26849    BC068290         16        33946311      33946311                G
# 26850   LINC00273         16        33946311      33946311                G
# 26851    BC068290         16        33946311      33946311                G
# 26852   LINC00273         16        33946311      33946311                G
# 26853    BC068290         16        33946373      33946373                C
# 26854   LINC00273         16        33946373      33946373                C
# 26855    BC068290         16        33946380      33946380                G
# 26856   LINC00273         16        33946380      33946380                G
# 26857    BC068290         16        33946393      33946393                C
# 26858   LINC00273         16        33946393      33946393                C
# 26859    BC068290         16        33946393      33946393                C
# 26860   LINC00273         16        33946393      33946393                C
# 26861    BC068290         16        33946432      33946432                G
# 26862   LINC00273         16        33946432      33946432                G
# 26863    BC068290         16        33946432      33946432                G
# 26864   LINC00273         16        33946432      33946432                G
# 26865    BC068290         16        33946432      33946432                G
# 26866   LINC00273         16        33946432      33946432                G
# 26867    BC068290         16        33946432      33946432                G
# 26868   LINC00273         16        33946432      33946432                G
#
#       Tumor_Seq_Allele2 Variant_Type Variant_Classification  \
# 0                     C          SNP                    IGR
# 1                     C          SNP                    IGR
# 2                     T          SNP                    IGR
# 3                     T          SNP                    IGR
# 4                     G          SNP                    RNA
# 5                     A          SNP                    IGR
# 6                     A          SNP                    IGR
# 7                     T          SNP                    IGR
# 8                     T          SNP                    IGR
# 9                     A          SNP                    IGR
# 10                    A          SNP                    IGR
# 11                    A          SNP                    IGR
# 12                    A          SNP                    IGR
# 13                    T          SNP                    IGR
# 14                    T          SNP                    IGR
# 15                    A          SNP                    IGR
# 16                    A          SNP                    IGR
# 17                    A          SNP                    IGR
# 18                    A          SNP                    IGR
# 19                    C          SNP                    IGR
# 20                    C          SNP                    IGR
# 21                    G          SNP                    IGR
# 22                    G          SNP                    IGR
# 23                    T          SNP                    IGR
# 24                    T          SNP                    IGR
# 25                    G          SNP                    IGR
# 26                    G          SNP                    IGR
# 27                    T          SNP                    IGR
# 28                    T          SNP                    IGR
# 29                    A          SNP                5'Flank
# ...                 ...          ...                    ...
# 26839                 A          SNP                    IGR
# 26840                 A          SNP                    IGR
# 26841                 A          SNP                    IGR
# 26842                 A          SNP                    IGR
# 26843                 A          SNP                    IGR
# 26844                 A          SNP                    IGR
# 26845                 T          SNP                    IGR
# 26846                 T          SNP                    IGR
# 26847                 T          SNP                    IGR
# 26848                 T          SNP                    IGR
# 26849                 T          SNP                    IGR
# 26850                 T          SNP                    IGR
# 26851                 T          SNP                    IGR
# 26852                 T          SNP                    IGR
# 26853                 T          SNP                    IGR
# 26854                 T          SNP                    IGR
# 26855                 T          SNP                    IGR
# 26856                 T          SNP                    IGR
# 26857                 T          SNP                    IGR
# 26858                 T          SNP                    IGR
# 26859                 T          SNP                    IGR
# 26860                 T          SNP                    IGR
# 26861                 A          SNP                    IGR
# 26862                 A          SNP                    IGR
# 26863                 A          SNP                    IGR
# 26864                 A          SNP                    IGR
# 26865                 A          SNP                    IGR
# 26866                 A          SNP                    IGR
# 26867                 A          SNP                    IGR
# 26868                 A          SNP                    IGR
#
#       Tumor_Sample_Barcode      dbSNP_RS           ...            notfound  \
# 0               N43_vs_T43   rs370901073           ...                 NaN
# 1               N43_vs_T43   rs370901073           ...                 NaN
# 2               N50_vs_T50   rs866556502           ...                 NaN
# 3               N50_vs_T50   rs866556502           ...                 NaN
# 4                 N6_vs_T6   rs377224548           ...                 NaN
# 5               N33_vs_T33     rs4269641           ...                 NaN
# 6               N33_vs_T33     rs4269641           ...                 NaN
# 7               N47_vs_T47    rs62563631           ...                 NaN
# 8               N47_vs_T47    rs62563631           ...                 NaN
# 9                 N8_vs_T8   rs199650048           ...                 NaN
# 10                N8_vs_T8   rs199650048           ...                 NaN
# 11              N35_vs_T35   rs375920469           ...                 NaN
# 12              N35_vs_T35   rs375920469           ...                 NaN
# 13              N50_vs_T50   rs370172818           ...                 NaN
# 14              N50_vs_T50   rs370172818           ...                 NaN
# 15              N49_vs_T49  rs1420752511           ...                 NaN
# 16              N49_vs_T49  rs1420752511           ...                 NaN
# 17              N47_vs_T47   rs138093336           ...                 NaN
# 18              N47_vs_T47   rs138093336           ...                 NaN
# 19              N29_vs_T29   rs200041314           ...                 NaN
# 20              N29_vs_T29   rs200041314           ...                 NaN
# 21              N29_vs_T29   rs200971657           ...                 NaN
# 22              N29_vs_T29   rs200971657           ...                 NaN
# 23              N29_vs_T29   rs201501781           ...                 NaN
# 24              N29_vs_T29   rs201501781           ...                 NaN
# 25              N44_vs_T44    rs60597100           ...                 NaN
# 26              N44_vs_T44    rs60597100           ...                 NaN
# 27              N11_vs_T11   rs879464958           ...                 NaN
# 28              N11_vs_T11   rs879464958           ...                 NaN
# 29              N11_vs_T11   rs201970274           ...                 NaN
# ...                    ...           ...           ...                 ...
# 26839           N17_vs_T17   rs140652923           ...                 NaN
# 26840           N17_vs_T17   rs140652923           ...                 NaN
# 26841           N36_vs_T36   rs140652923           ...                 NaN
# 26842           N36_vs_T36   rs140652923           ...                 NaN
# 26843           N43_vs_T43   rs140652923           ...                 NaN
# 26844           N43_vs_T43   rs140652923           ...                 NaN
# 26845           N10_vs_T10   rs140652923           ...                 NaN
# 26846           N10_vs_T10   rs140652923           ...                 NaN
# 26847           N17_vs_T17   rs140652923           ...                 NaN
# 26848           N17_vs_T17   rs140652923           ...                 NaN
# 26849           N36_vs_T36   rs140652923           ...                 NaN
# 26850           N36_vs_T36   rs140652923           ...                 NaN
# 26851           N43_vs_T43   rs140652923           ...                 NaN
# 26852           N43_vs_T43   rs140652923           ...                 NaN
# 26853             N3_vs_T3   rs878993855           ...                 NaN
# 26854             N3_vs_T3   rs878993855           ...                 NaN
# 26855             N3_vs_T3   rs796875062           ...                 NaN
# 26856             N3_vs_T3   rs796875062           ...                 NaN
# 26857             N3_vs_T3   rs372509388           ...                 NaN
# 26858             N3_vs_T3   rs372509388           ...                 NaN
# 26859           N39_vs_T39   rs372509388           ...                 NaN
# 26860           N39_vs_T39   rs372509388           ...                 NaN
# 26861           N18_vs_T18   rs201531637           ...                 NaN
# 26862           N18_vs_T18   rs201531637           ...                 NaN
# 26863             N2_vs_T2   rs201531637           ...                 NaN
# 26864             N2_vs_T2   rs201531637           ...                 NaN
# 26865             N1_vs_T1   rs201531637           ...                 NaN
# 26866             N1_vs_T1   rs201531637           ...                 NaN
# 26867           N23_vs_T23   rs201531637           ...                 NaN
# 26868           N23_vs_T23   rs201531637           ...                 NaN
#
#        samples.filter_passing_reads_count  samples.genotype  \
# 0                                       3              None
# 1                                       3              None
# 2                                      10              None
# 3                                      10              None
# 4                                       4              None
# 5                                       6              None
# 6                                       6              None
# 7                                       5              None
# 8                                       5              None
# 9                                       5              None
# 10                                      5              None
# 11                                     13              None
# 12                                     13              None
# 13                                     19              None
# 14                                     19              None
# 15                                      5              None
# 16                                      5              None
# 17                                     11              None
# 18                                     11              None
# 19                                      5              None
# 20                                      5              None
# 21                                      6              None
# 22                                      6              None
# 23                                      8              None
# 24                                      8              None
# 25                                      9              None
# 26                                      9              None
# 27                                     11              None
# 28                                     11              None
# 29                                     10              None
# ...                                   ...               ...
# 26839                                   9              None
# 26840                                   9              None
# 26841                                  12              None
# 26842                                  12              None
# 26843                                  17              None
# 26844                                  17              None
# 26845                                  18              None
# 26846                                  18              None
# 26847                                   9              None
# 26848                                   9              None
# 26849                                  12              None
# 26850                                  12              None
# 26851                                  17              None
# 26852                                  17              None
# 26853                                  14              None
# 26854                                  14              None
# 26855                                  10              None
# 26856                                  10              None
# 26857                                  10              None
# 26858                                  10              None
# 26859                                  14              None
# 26860                                  14              None
# 26861                                  13              None
# 26862                                  13              None
# 26863                                  12              None
# 26864                                  12              None
# 26865                                  11              None
# 26866                                  11              None
# 26867                                  13              None
# 26868                                  13              None
#
#           wellderly._license  wellderly.alleles.allele1  \
# 0      https://goo.gl/e8OO17                          A
# 1      https://goo.gl/e8OO17                          A
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4      https://goo.gl/e8OO17                          A
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13     https://goo.gl/e8OO17                          C
# 14     https://goo.gl/e8OO17                          C
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
# 20                       NaN                        NaN
# 21                       NaN                        NaN
# 22                       NaN                        NaN
# 23                       NaN                        NaN
# 24                       NaN                        NaN
# 25                       NaN                        NaN
# 26                       NaN                        NaN
# 27                       NaN                        NaN
# 28                       NaN                        NaN
# 29     https://goo.gl/e8OO17                          A
# ...                      ...                        ...
# 26839                    NaN                        NaN
# 26840                    NaN                        NaN
# 26841                    NaN                        NaN
# 26842                    NaN                        NaN
# 26843                    NaN                        NaN
# 26844                    NaN                        NaN
# 26845                    NaN                        NaN
# 26846                    NaN                        NaN
# 26847                    NaN                        NaN
# 26848                    NaN                        NaN
# 26849                    NaN                        NaN
# 26850                    NaN                        NaN
# 26851                    NaN                        NaN
# 26852                    NaN                        NaN
# 26853                    NaN                        NaN
# 26854                    NaN                        NaN
# 26855                    NaN                        NaN
# 26856                    NaN                        NaN
# 26857                    NaN                        NaN
# 26858                    NaN                        NaN
# 26859                    NaN                        NaN
# 26860                    NaN                        NaN
# 26861                    NaN                        NaN
# 26862                    NaN                        NaN
# 26863                    NaN                        NaN
# 26864                    NaN                        NaN
# 26865                    NaN                        NaN
# 26866                    NaN                        NaN
# 26867                    NaN                        NaN
# 26868                    NaN                        NaN
#
#        wellderly.alleles.allele2  wellderly.alleles.allele3  \
# 0                              C                        NaN
# 1                              C                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                              G                        NaN
# 5                            NaN                        NaN
# 6                            NaN                        NaN
# 7                            NaN                        NaN
# 8                            NaN                        NaN
# 9                            NaN                        NaN
# 10                           NaN                        NaN
# 11                           NaN                        NaN
# 12                           NaN                        NaN
# 13                             T                        NaN
# 14                             T                        NaN
# 15                           NaN                        NaN
# 16                           NaN                        NaN
# 17                           NaN                        NaN
# 18                           NaN                        NaN
# 19                           NaN                        NaN
# 20                           NaN                        NaN
# 21                           NaN                        NaN
# 22                           NaN                        NaN
# 23                           NaN                        NaN
# 24                           NaN                        NaN
# 25                           NaN                        NaN
# 26                           NaN                        NaN
# 27                           NaN                        NaN
# 28                           NaN                        NaN
# 29                             G                        NaN
# ...                          ...                        ...
# 26839                        NaN                        NaN
# 26840                        NaN                        NaN
# 26841                        NaN                        NaN
# 26842                        NaN                        NaN
# 26843                        NaN                        NaN
# 26844                        NaN                        NaN
# 26845                        NaN                        NaN
# 26846                        NaN                        NaN
# 26847                        NaN                        NaN
# 26848                        NaN                        NaN
# 26849                        NaN                        NaN
# 26850                        NaN                        NaN
# 26851                        NaN                        NaN
# 26852                        NaN                        NaN
# 26853                        NaN                        NaN
# 26854                        NaN                        NaN
# 26855                        NaN                        NaN
# 26856                        NaN                        NaN
# 26857                        NaN                        NaN
# 26858                        NaN                        NaN
# 26859                        NaN                        NaN
# 26860                        NaN                        NaN
# 26861                        NaN                        NaN
# 26862                        NaN                        NaN
# 26863                        NaN                        NaN
# 26864                        NaN                        NaN
# 26865                        NaN                        NaN
# 26866                        NaN                        NaN
# 26867                        NaN                        NaN
# 26868                        NaN                        NaN
#
#        wellderly.alleles.freq1  wellderly.alleles.freq2  \
# 0                       0.8675                   0.1325
# 1                       0.8675                   0.1325
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                       0.8850                   0.1150
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                      0.9025                   0.0975
# 14                      0.9025                   0.0975
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# 26                         NaN                      NaN
# 27                         NaN                      NaN
# 28                         NaN                      NaN
# 29                      0.0175                   0.9825
# ...                        ...                      ...
# 26839                      NaN                      NaN
# 26840                      NaN                      NaN
# 26841                      NaN                      NaN
# 26842                      NaN                      NaN
# 26843                      NaN                      NaN
# 26844                      NaN                      NaN
# 26845                      NaN                      NaN
# 26846                      NaN                      NaN
# 26847                      NaN                      NaN
# 26848                      NaN                      NaN
# 26849                      NaN                      NaN
# 26850                      NaN                      NaN
# 26851                      NaN                      NaN
# 26852                      NaN                      NaN
# 26853                      NaN                      NaN
# 26854                      NaN                      NaN
# 26855                      NaN                      NaN
# 26856                      NaN                      NaN
# 26857                      NaN                      NaN
# 26858                      NaN                      NaN
# 26859                      NaN                      NaN
# 26860                      NaN                      NaN
# 26861                      NaN                      NaN
# 26862                      NaN                      NaN
# 26863                      NaN                      NaN
# 26864                      NaN                      NaN
# 26865                      NaN                      NaN
# 26866                      NaN                      NaN
# 26867                      NaN                      NaN
# 26868                      NaN                      NaN
#
#       wellderly.alleles.freq3
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ...                       ...
# 26839                     NaN
# 26840                     NaN
# 26841                     NaN
# 26842                     NaN
# 26843                     NaN
# 26844                     NaN
# 26845                     NaN
# 26846                     NaN
# 26847                     NaN
# 26848                     NaN
# 26849                     NaN
# 26850                     NaN
# 26851                     NaN
# 26852                     NaN
# 26853                     NaN
# 26854                     NaN
# 26855                     NaN
# 26856                     NaN
# 26857                     NaN
# 26858                     NaN
# 26859                     NaN
# 26860                     NaN
# 26861                     NaN
# 26862                     NaN
# 26863                     NaN
# 26864                     NaN
# 26865                     NaN
# 26866                     NaN
# 26867                     NaN
# 26868                     NaN
#
# [26869 rows x 1065 columns]

# %%
cols = list(df2)
for x in cols:
    print(x)
# Out:
# Hugo_Symbol
# Chromosome
# Start_Position
# End_Position
# Reference_Allele
# Tumor_Seq_Allele2
# Variant_Type
# Variant_Classification
# Tumor_Sample_Barcode
# dbSNP_RS
# t_ref_count
# t_alt_count
# 1000g2015aug_all
# _id
# cadd.1000g.af
# AFR_MAF
# AMR_MAF
# ASN_MAF
# EUR_MAF
# cadd._license
# cadd.esp.af
# cadd.esp.afr
# cadd.esp.eur
# cadd.gerp.n
# cadd.gerp.rs
# cadd.gerp.rs_pval
# cadd.gerp.s
# cadd.phred
# cadd.polyphen.cat
# cadd.polyphen.cat1
# cadd.polyphen.cat2
# cadd.polyphen.val
# cadd.polyphen.val1
# cadd.polyphen.val2
# cadd.sift.cat
# cadd.sift.val
# cgi._license
# cgi.association
# cgi.cdna
# cgi.drug
# cgi.evidence_level
# cgi.gene
# cgi.primary_tumor_type
# cgi.protein_change
# cgi.region
# cgi.source
# cgi.transcript
# civic._license
# civic.description
# civic.evidence_items.clinical_significance
# civic.evidence_items.clinical_significance1
# civic.evidence_items.clinical_significance10
# civic.evidence_items.clinical_significance11
# civic.evidence_items.clinical_significance12
# civic.evidence_items.clinical_significance13
# civic.evidence_items.clinical_significance14
# civic.evidence_items.clinical_significance15
# civic.evidence_items.clinical_significance16
# civic.evidence_items.clinical_significance17
# civic.evidence_items.clinical_significance18
# civic.evidence_items.clinical_significance19
# civic.evidence_items.clinical_significance2
# civic.evidence_items.clinical_significance20
# civic.evidence_items.clinical_significance21
# civic.evidence_items.clinical_significance3
# civic.evidence_items.clinical_significance4
# civic.evidence_items.clinical_significance5
# civic.evidence_items.clinical_significance6
# civic.evidence_items.clinical_significance7
# civic.evidence_items.clinical_significance8
# civic.evidence_items.clinical_significance9
# civic.evidence_items.description
# civic.evidence_items.description1
# civic.evidence_items.description10
# civic.evidence_items.description11
# civic.evidence_items.description12
# civic.evidence_items.description13
# civic.evidence_items.description14
# civic.evidence_items.description15
# civic.evidence_items.description16
# civic.evidence_items.description17
# civic.evidence_items.description18
# civic.evidence_items.description19
# civic.evidence_items.description2
# civic.evidence_items.description20
# civic.evidence_items.description21
# civic.evidence_items.description3
# civic.evidence_items.description4
# civic.evidence_items.description5
# civic.evidence_items.description6
# civic.evidence_items.description7
# civic.evidence_items.description8
# civic.evidence_items.description9
# civic.evidence_items.disease.display_name
# civic.evidence_items.disease.doid
# civic.evidence_items.disease.id
# civic.evidence_items.disease.name
# civic.evidence_items.disease.url
# civic.evidence_items.disease1.display_name
# civic.evidence_items.disease1.doid
# civic.evidence_items.disease1.id
# civic.evidence_items.disease1.name
# civic.evidence_items.disease1.url
# civic.evidence_items.disease10.display_name
# civic.evidence_items.disease10.doid
# civic.evidence_items.disease10.id
# civic.evidence_items.disease10.name
# civic.evidence_items.disease10.url
# civic.evidence_items.disease11.display_name
# civic.evidence_items.disease11.doid
# civic.evidence_items.disease11.id
# civic.evidence_items.disease11.name
# civic.evidence_items.disease11.url
# civic.evidence_items.disease12.display_name
# civic.evidence_items.disease12.doid
# civic.evidence_items.disease12.id
# civic.evidence_items.disease12.name
# civic.evidence_items.disease12.url
# civic.evidence_items.disease13.display_name
# civic.evidence_items.disease13.doid
# civic.evidence_items.disease13.id
# civic.evidence_items.disease13.name
# civic.evidence_items.disease13.url
# civic.evidence_items.disease14.display_name
# civic.evidence_items.disease14.doid
# civic.evidence_items.disease14.id
# civic.evidence_items.disease14.name
# civic.evidence_items.disease14.url
# civic.evidence_items.disease15.display_name
# civic.evidence_items.disease15.doid
# civic.evidence_items.disease15.id
# civic.evidence_items.disease15.name
# civic.evidence_items.disease15.url
# civic.evidence_items.disease16.display_name
# civic.evidence_items.disease16.doid
# civic.evidence_items.disease16.id
# civic.evidence_items.disease16.name
# civic.evidence_items.disease16.url
# civic.evidence_items.disease17.display_name
# civic.evidence_items.disease17.doid
# civic.evidence_items.disease17.id
# civic.evidence_items.disease17.name
# civic.evidence_items.disease17.url
# civic.evidence_items.disease18.display_name
# civic.evidence_items.disease18.doid
# civic.evidence_items.disease18.id
# civic.evidence_items.disease18.name
# civic.evidence_items.disease18.url
# civic.evidence_items.disease19.display_name
# civic.evidence_items.disease19.doid
# civic.evidence_items.disease19.id
# civic.evidence_items.disease19.name
# civic.evidence_items.disease19.url
# civic.evidence_items.disease2.display_name
# civic.evidence_items.disease2.doid
# civic.evidence_items.disease2.id
# civic.evidence_items.disease2.name
# civic.evidence_items.disease2.url
# civic.evidence_items.disease20.display_name
# civic.evidence_items.disease20.doid
# civic.evidence_items.disease20.id
# civic.evidence_items.disease20.name
# civic.evidence_items.disease20.url
# civic.evidence_items.disease21.display_name
# civic.evidence_items.disease21.doid
# civic.evidence_items.disease21.id
# civic.evidence_items.disease21.name
# civic.evidence_items.disease21.url
# civic.evidence_items.disease3.display_name
# civic.evidence_items.disease3.doid
# civic.evidence_items.disease3.id
# civic.evidence_items.disease3.name
# civic.evidence_items.disease3.url
# civic.evidence_items.disease4.display_name
# civic.evidence_items.disease4.doid
# civic.evidence_items.disease4.id
# civic.evidence_items.disease4.name
# civic.evidence_items.disease4.url
# civic.evidence_items.disease5.display_name
# civic.evidence_items.disease5.doid
# civic.evidence_items.disease5.id
# civic.evidence_items.disease5.name
# civic.evidence_items.disease5.url
# civic.evidence_items.disease6.display_name
# civic.evidence_items.disease6.doid
# civic.evidence_items.disease6.id
# civic.evidence_items.disease6.name
# civic.evidence_items.disease6.url
# civic.evidence_items.disease7.display_name
# civic.evidence_items.disease7.doid
# civic.evidence_items.disease7.id
# civic.evidence_items.disease7.name
# civic.evidence_items.disease7.url
# civic.evidence_items.disease8.display_name
# civic.evidence_items.disease8.doid
# civic.evidence_items.disease8.id
# civic.evidence_items.disease8.name
# civic.evidence_items.disease8.url
# civic.evidence_items.disease9.display_name
# civic.evidence_items.disease9.doid
# civic.evidence_items.disease9.id
# civic.evidence_items.disease9.name
# civic.evidence_items.disease9.url
# civic.evidence_items.drug_interaction_type1
# civic.evidence_items.drug_interaction_type15
# civic.evidence_items.drug_interaction_type18
# civic.evidence_items.drug_interaction_type2
# civic.evidence_items.drug_interaction_type7
# civic.evidence_items.drugs1
# civic.evidence_items.drugs10
# civic.evidence_items.drugs11
# civic.evidence_items.drugs12
# civic.evidence_items.drugs13
# civic.evidence_items.drugs14
# civic.evidence_items.drugs15
# civic.evidence_items.drugs16
# civic.evidence_items.drugs17
# civic.evidence_items.drugs18
# civic.evidence_items.drugs19
# civic.evidence_items.drugs2
# civic.evidence_items.drugs3
# civic.evidence_items.drugs4
# civic.evidence_items.drugs5
# civic.evidence_items.drugs6
# civic.evidence_items.drugs7
# civic.evidence_items.drugs8
# civic.evidence_items.drugs9
# civic.evidence_items.evidence_direction
# civic.evidence_items.evidence_direction1
# civic.evidence_items.evidence_direction10
# civic.evidence_items.evidence_direction11
# civic.evidence_items.evidence_direction12
# civic.evidence_items.evidence_direction13
# civic.evidence_items.evidence_direction14
# civic.evidence_items.evidence_direction15
# civic.evidence_items.evidence_direction16
# civic.evidence_items.evidence_direction17
# civic.evidence_items.evidence_direction18
# civic.evidence_items.evidence_direction19
# civic.evidence_items.evidence_direction2
# civic.evidence_items.evidence_direction20
# civic.evidence_items.evidence_direction21
# civic.evidence_items.evidence_direction3
# civic.evidence_items.evidence_direction4
# civic.evidence_items.evidence_direction5
# civic.evidence_items.evidence_direction6
# civic.evidence_items.evidence_direction7
# civic.evidence_items.evidence_direction8
# civic.evidence_items.evidence_direction9
# civic.evidence_items.evidence_level
# civic.evidence_items.evidence_level1
# civic.evidence_items.evidence_level10
# civic.evidence_items.evidence_level11
# civic.evidence_items.evidence_level12
# civic.evidence_items.evidence_level13
# civic.evidence_items.evidence_level14
# civic.evidence_items.evidence_level15
# civic.evidence_items.evidence_level16
# civic.evidence_items.evidence_level17
# civic.evidence_items.evidence_level18
# civic.evidence_items.evidence_level19
# civic.evidence_items.evidence_level2
# civic.evidence_items.evidence_level20
# civic.evidence_items.evidence_level21
# civic.evidence_items.evidence_level3
# civic.evidence_items.evidence_level4
# civic.evidence_items.evidence_level5
# civic.evidence_items.evidence_level6
# civic.evidence_items.evidence_level7
# civic.evidence_items.evidence_level8
# civic.evidence_items.evidence_level9
# civic.evidence_items.evidence_type
# civic.evidence_items.evidence_type1
# civic.evidence_items.evidence_type10
# civic.evidence_items.evidence_type11
# civic.evidence_items.evidence_type12
# civic.evidence_items.evidence_type13
# civic.evidence_items.evidence_type14
# civic.evidence_items.evidence_type15
# civic.evidence_items.evidence_type16
# civic.evidence_items.evidence_type17
# civic.evidence_items.evidence_type18
# civic.evidence_items.evidence_type19
# civic.evidence_items.evidence_type2
# civic.evidence_items.evidence_type20
# civic.evidence_items.evidence_type21
# civic.evidence_items.evidence_type3
# civic.evidence_items.evidence_type4
# civic.evidence_items.evidence_type5
# civic.evidence_items.evidence_type6
# civic.evidence_items.evidence_type7
# civic.evidence_items.evidence_type8
# civic.evidence_items.evidence_type9
# civic.evidence_items.id
# civic.evidence_items.id1
# civic.evidence_items.id10
# civic.evidence_items.id11
# civic.evidence_items.id12
# civic.evidence_items.id13
# civic.evidence_items.id14
# civic.evidence_items.id15
# civic.evidence_items.id16
# civic.evidence_items.id17
# civic.evidence_items.id18
# civic.evidence_items.id19
# civic.evidence_items.id2
# civic.evidence_items.id20
# civic.evidence_items.id21
# civic.evidence_items.id3
# civic.evidence_items.id4
# civic.evidence_items.id5
# civic.evidence_items.id6
# civic.evidence_items.id7
# civic.evidence_items.id8
# civic.evidence_items.id9
# civic.evidence_items.name
# civic.evidence_items.name1
# civic.evidence_items.name10
# civic.evidence_items.name11
# civic.evidence_items.name12
# civic.evidence_items.name13
# civic.evidence_items.name14
# civic.evidence_items.name15
# civic.evidence_items.name16
# civic.evidence_items.name17
# civic.evidence_items.name18
# civic.evidence_items.name19
# civic.evidence_items.name2
# civic.evidence_items.name20
# civic.evidence_items.name21
# civic.evidence_items.name3
# civic.evidence_items.name4
# civic.evidence_items.name5
# civic.evidence_items.name6
# civic.evidence_items.name7
# civic.evidence_items.name8
# civic.evidence_items.name9
# civic.evidence_items.open_change_count
# civic.evidence_items.open_change_count1
# civic.evidence_items.open_change_count10
# civic.evidence_items.open_change_count11
# civic.evidence_items.open_change_count12
# civic.evidence_items.open_change_count13
# civic.evidence_items.open_change_count14
# civic.evidence_items.open_change_count15
# civic.evidence_items.open_change_count16
# civic.evidence_items.open_change_count17
# civic.evidence_items.open_change_count18
# civic.evidence_items.open_change_count19
# civic.evidence_items.open_change_count2
# civic.evidence_items.open_change_count20
# civic.evidence_items.open_change_count21
# civic.evidence_items.open_change_count3
# civic.evidence_items.open_change_count4
# civic.evidence_items.open_change_count5
# civic.evidence_items.open_change_count6
# civic.evidence_items.open_change_count7
# civic.evidence_items.open_change_count8
# civic.evidence_items.open_change_count9
# civic.evidence_items.rating
# civic.evidence_items.rating1
# civic.evidence_items.rating13
# civic.evidence_items.rating14
# civic.evidence_items.rating15
# civic.evidence_items.rating16
# civic.evidence_items.rating17
# civic.evidence_items.rating18
# civic.evidence_items.rating2
# civic.evidence_items.rating20
# civic.evidence_items.rating21
# civic.evidence_items.rating3
# civic.evidence_items.rating4
# civic.evidence_items.rating5
# civic.evidence_items.rating6
# civic.evidence_items.rating7
# civic.evidence_items.source.citation
# civic.evidence_items.source.full_journal_title
# civic.evidence_items.source.id
# civic.evidence_items.source.is_review
# civic.evidence_items.source.journal
# civic.evidence_items.source.name
# civic.evidence_items.source.open_access
# civic.evidence_items.source.pmc_id
# civic.evidence_items.source.publication_date.year
# civic.evidence_items.source.pubmed_id
# civic.evidence_items.source.source_url
# civic.evidence_items.source.status
# civic.evidence_items.source1.citation
# civic.evidence_items.source1.full_journal_title
# civic.evidence_items.source1.id
# civic.evidence_items.source1.is_review
# civic.evidence_items.source1.journal
# civic.evidence_items.source1.name
# civic.evidence_items.source1.open_access
# civic.evidence_items.source1.pmc_id
# civic.evidence_items.source1.publication_date.day
# civic.evidence_items.source1.publication_date.month
# civic.evidence_items.source1.publication_date.year
# civic.evidence_items.source1.pubmed_id
# civic.evidence_items.source1.source_url
# civic.evidence_items.source1.status
# civic.evidence_items.source10.citation
# civic.evidence_items.source10.full_journal_title
# civic.evidence_items.source10.id
# civic.evidence_items.source10.is_review
# civic.evidence_items.source10.journal
# civic.evidence_items.source10.name
# civic.evidence_items.source10.publication_date.day
# civic.evidence_items.source10.publication_date.month
# civic.evidence_items.source10.publication_date.year
# civic.evidence_items.source10.pubmed_id
# civic.evidence_items.source10.source_url
# civic.evidence_items.source10.status
# civic.evidence_items.source11.citation
# civic.evidence_items.source11.full_journal_title
# civic.evidence_items.source11.id
# civic.evidence_items.source11.is_review
# civic.evidence_items.source11.journal
# civic.evidence_items.source11.name
# civic.evidence_items.source11.publication_date.day
# civic.evidence_items.source11.publication_date.month
# civic.evidence_items.source11.publication_date.year
# civic.evidence_items.source11.pubmed_id
# civic.evidence_items.source11.source_url
# civic.evidence_items.source11.status
# civic.evidence_items.source12.citation
# civic.evidence_items.source12.full_journal_title
# civic.evidence_items.source12.id
# civic.evidence_items.source12.is_review
# civic.evidence_items.source12.journal
# civic.evidence_items.source12.name
# civic.evidence_items.source12.open_access
# civic.evidence_items.source12.pmc_id
# civic.evidence_items.source12.publication_date.day
# civic.evidence_items.source12.publication_date.month
# civic.evidence_items.source12.publication_date.year
# civic.evidence_items.source12.pubmed_id
# civic.evidence_items.source12.source_url
# civic.evidence_items.source12.status
# civic.evidence_items.source13.citation
# civic.evidence_items.source13.full_journal_title
# civic.evidence_items.source13.id
# civic.evidence_items.source13.is_review
# civic.evidence_items.source13.journal
# civic.evidence_items.source13.name
# civic.evidence_items.source13.open_access
# civic.evidence_items.source13.pmc_id
# civic.evidence_items.source13.publication_date.day
# civic.evidence_items.source13.publication_date.month
# civic.evidence_items.source13.publication_date.year
# civic.evidence_items.source13.pubmed_id
# civic.evidence_items.source13.source_url
# civic.evidence_items.source13.status
# civic.evidence_items.source14.citation
# civic.evidence_items.source14.full_journal_title
# civic.evidence_items.source14.id
# civic.evidence_items.source14.is_review
# civic.evidence_items.source14.journal
# civic.evidence_items.source14.name
# civic.evidence_items.source14.open_access
# civic.evidence_items.source14.pmc_id
# civic.evidence_items.source14.publication_date.day
# civic.evidence_items.source14.publication_date.month
# civic.evidence_items.source14.publication_date.year
# civic.evidence_items.source14.pubmed_id
# civic.evidence_items.source14.source_url
# civic.evidence_items.source14.status
# civic.evidence_items.source15.citation
# civic.evidence_items.source15.full_journal_title
# civic.evidence_items.source15.id
# civic.evidence_items.source15.is_review
# civic.evidence_items.source15.journal
# civic.evidence_items.source15.name
# civic.evidence_items.source15.open_access
# civic.evidence_items.source15.pmc_id
# civic.evidence_items.source15.publication_date.day
# civic.evidence_items.source15.publication_date.month
# civic.evidence_items.source15.publication_date.year
# civic.evidence_items.source15.pubmed_id
# civic.evidence_items.source15.source_url
# civic.evidence_items.source15.status
# civic.evidence_items.source16.citation
# civic.evidence_items.source16.full_journal_title
# civic.evidence_items.source16.id
# civic.evidence_items.source16.is_review
# civic.evidence_items.source16.journal
# civic.evidence_items.source16.name
# civic.evidence_items.source16.open_access
# civic.evidence_items.source16.pmc_id
# civic.evidence_items.source16.publication_date.day
# civic.evidence_items.source16.publication_date.month
# civic.evidence_items.source16.publication_date.year
# civic.evidence_items.source16.pubmed_id
# civic.evidence_items.source16.source_url
# civic.evidence_items.source16.status
# civic.evidence_items.source17.citation
# civic.evidence_items.source17.full_journal_title
# civic.evidence_items.source17.id
# civic.evidence_items.source17.is_review
# civic.evidence_items.source17.journal
# civic.evidence_items.source17.name
# civic.evidence_items.source17.open_access
# civic.evidence_items.source17.pmc_id
# civic.evidence_items.source17.publication_date.month
# civic.evidence_items.source17.publication_date.year
# civic.evidence_items.source17.pubmed_id
# civic.evidence_items.source17.source_url
# civic.evidence_items.source17.status
# civic.evidence_items.source18.citation
# civic.evidence_items.source18.full_journal_title
# civic.evidence_items.source18.id
# civic.evidence_items.source18.is_review
# civic.evidence_items.source18.journal
# civic.evidence_items.source18.name
# civic.evidence_items.source18.open_access
# civic.evidence_items.source18.pmc_id
# civic.evidence_items.source18.publication_date.day
# civic.evidence_items.source18.publication_date.month
# civic.evidence_items.source18.publication_date.year
# civic.evidence_items.source18.pubmed_id
# civic.evidence_items.source18.source_url
# civic.evidence_items.source18.status
# civic.evidence_items.source19.citation
# civic.evidence_items.source19.full_journal_title
# civic.evidence_items.source19.id
# civic.evidence_items.source19.is_review
# civic.evidence_items.source19.journal
# civic.evidence_items.source19.name
# civic.evidence_items.source19.open_access
# civic.evidence_items.source19.pmc_id
# civic.evidence_items.source19.publication_date.month
# civic.evidence_items.source19.publication_date.year
# civic.evidence_items.source19.pubmed_id
# civic.evidence_items.source19.source_url
# civic.evidence_items.source19.status
# civic.evidence_items.source2.citation
# civic.evidence_items.source2.full_journal_title
# civic.evidence_items.source2.id
# civic.evidence_items.source2.is_review
# civic.evidence_items.source2.journal
# civic.evidence_items.source2.name
# civic.evidence_items.source2.open_access
# civic.evidence_items.source2.pmc_id
# civic.evidence_items.source2.publication_date.day
# civic.evidence_items.source2.publication_date.month
# civic.evidence_items.source2.publication_date.year
# civic.evidence_items.source2.pubmed_id
# civic.evidence_items.source2.source_url
# civic.evidence_items.source2.status
# civic.evidence_items.source20.citation
# civic.evidence_items.source20.full_journal_title
# civic.evidence_items.source20.id
# civic.evidence_items.source20.is_review
# civic.evidence_items.source20.journal
# civic.evidence_items.source20.name
# civic.evidence_items.source20.open_access
# civic.evidence_items.source20.pmc_id
# civic.evidence_items.source20.publication_date.day
# civic.evidence_items.source20.publication_date.month
# civic.evidence_items.source20.publication_date.year
# civic.evidence_items.source20.pubmed_id
# civic.evidence_items.source20.source_url
# civic.evidence_items.source20.status
# civic.evidence_items.source21.citation
# civic.evidence_items.source21.full_journal_title
# civic.evidence_items.source21.id
# civic.evidence_items.source21.is_review
# civic.evidence_items.source21.journal
# civic.evidence_items.source21.name
# civic.evidence_items.source21.publication_date.day
# civic.evidence_items.source21.publication_date.month
# civic.evidence_items.source21.publication_date.year
# civic.evidence_items.source21.pubmed_id
# civic.evidence_items.source21.source_url
# civic.evidence_items.source21.status
# civic.evidence_items.source3.citation
# civic.evidence_items.source3.full_journal_title
# civic.evidence_items.source3.id
# civic.evidence_items.source3.is_review
# civic.evidence_items.source3.journal
# civic.evidence_items.source3.name
# civic.evidence_items.source3.open_access
# civic.evidence_items.source3.pmc_id
# civic.evidence_items.source3.publication_date.day
# civic.evidence_items.source3.publication_date.month
# civic.evidence_items.source3.publication_date.year
# civic.evidence_items.source3.pubmed_id
# civic.evidence_items.source3.source_url
# civic.evidence_items.source3.status
# civic.evidence_items.source4.citation
# civic.evidence_items.source4.full_journal_title
# civic.evidence_items.source4.id
# civic.evidence_items.source4.is_review
# civic.evidence_items.source4.journal
# civic.evidence_items.source4.name
# civic.evidence_items.source4.open_access
# civic.evidence_items.source4.pmc_id
# civic.evidence_items.source4.publication_date.day
# civic.evidence_items.source4.publication_date.month
# civic.evidence_items.source4.publication_date.year
# civic.evidence_items.source4.pubmed_id
# civic.evidence_items.source4.source_url
# civic.evidence_items.source4.status
# civic.evidence_items.source5.citation
# civic.evidence_items.source5.full_journal_title
# civic.evidence_items.source5.id
# civic.evidence_items.source5.is_review
# civic.evidence_items.source5.journal
# civic.evidence_items.source5.name
# civic.evidence_items.source5.open_access
# civic.evidence_items.source5.pmc_id
# civic.evidence_items.source5.publication_date.day
# civic.evidence_items.source5.publication_date.month
# civic.evidence_items.source5.publication_date.year
# civic.evidence_items.source5.pubmed_id
# civic.evidence_items.source5.source_url
# civic.evidence_items.source5.status
# civic.evidence_items.source6.citation
# civic.evidence_items.source6.full_journal_title
# civic.evidence_items.source6.id
# civic.evidence_items.source6.is_review
# civic.evidence_items.source6.journal
# civic.evidence_items.source6.name
# civic.evidence_items.source6.open_access
# civic.evidence_items.source6.pmc_id
# civic.evidence_items.source6.publication_date.day
# civic.evidence_items.source6.publication_date.month
# civic.evidence_items.source6.publication_date.year
# civic.evidence_items.source6.pubmed_id
# civic.evidence_items.source6.source_url
# civic.evidence_items.source6.status
# civic.evidence_items.source7.citation
# civic.evidence_items.source7.full_journal_title
# civic.evidence_items.source7.id
# civic.evidence_items.source7.is_review
# civic.evidence_items.source7.journal
# civic.evidence_items.source7.name
# civic.evidence_items.source7.open_access
# civic.evidence_items.source7.pmc_id
# civic.evidence_items.source7.publication_date.day
# civic.evidence_items.source7.publication_date.month
# civic.evidence_items.source7.publication_date.year
# civic.evidence_items.source7.pubmed_id
# civic.evidence_items.source7.source_url
# civic.evidence_items.source7.status
# civic.evidence_items.source8.citation
# civic.evidence_items.source8.full_journal_title
# civic.evidence_items.source8.id
# civic.evidence_items.source8.is_review
# civic.evidence_items.source8.journal
# civic.evidence_items.source8.name
# civic.evidence_items.source8.publication_date.day
# civic.evidence_items.source8.publication_date.month
# civic.evidence_items.source8.publication_date.year
# civic.evidence_items.source8.pubmed_id
# civic.evidence_items.source8.source_url
# civic.evidence_items.source8.status
# civic.evidence_items.source9.citation
# civic.evidence_items.source9.full_journal_title
# civic.evidence_items.source9.id
# civic.evidence_items.source9.is_review
# civic.evidence_items.source9.journal
# civic.evidence_items.source9.name
# civic.evidence_items.source9.open_access
# civic.evidence_items.source9.pmc_id
# civic.evidence_items.source9.publication_date.day
# civic.evidence_items.source9.publication_date.month
# civic.evidence_items.source9.publication_date.year
# civic.evidence_items.source9.pubmed_id
# civic.evidence_items.source9.source_url
# civic.evidence_items.source9.status
# civic.evidence_items.status
# civic.evidence_items.status1
# civic.evidence_items.status10
# civic.evidence_items.status11
# civic.evidence_items.status12
# civic.evidence_items.status13
# civic.evidence_items.status14
# civic.evidence_items.status15
# civic.evidence_items.status16
# civic.evidence_items.status17
# civic.evidence_items.status18
# civic.evidence_items.status19
# civic.evidence_items.status2
# civic.evidence_items.status20
# civic.evidence_items.status21
# civic.evidence_items.status3
# civic.evidence_items.status4
# civic.evidence_items.status5
# civic.evidence_items.status6
# civic.evidence_items.status7
# civic.evidence_items.status8
# civic.evidence_items.status9
# civic.evidence_items.type
# civic.evidence_items.type1
# civic.evidence_items.type10
# civic.evidence_items.type11
# civic.evidence_items.type12
# civic.evidence_items.type13
# civic.evidence_items.type14
# civic.evidence_items.type15
# civic.evidence_items.type16
# civic.evidence_items.type17
# civic.evidence_items.type18
# civic.evidence_items.type19
# civic.evidence_items.type2
# civic.evidence_items.type20
# civic.evidence_items.type21
# civic.evidence_items.type3
# civic.evidence_items.type4
# civic.evidence_items.type5
# civic.evidence_items.type6
# civic.evidence_items.type7
# civic.evidence_items.type8
# civic.evidence_items.type9
# civic.evidence_items.variant_id
# civic.evidence_items.variant_id1
# civic.evidence_items.variant_id10
# civic.evidence_items.variant_id11
# civic.evidence_items.variant_id12
# civic.evidence_items.variant_id13
# civic.evidence_items.variant_id14
# civic.evidence_items.variant_id15
# civic.evidence_items.variant_id16
# civic.evidence_items.variant_id17
# civic.evidence_items.variant_id18
# civic.evidence_items.variant_id19
# civic.evidence_items.variant_id2
# civic.evidence_items.variant_id20
# civic.evidence_items.variant_id21
# civic.evidence_items.variant_id3
# civic.evidence_items.variant_id4
# civic.evidence_items.variant_id5
# civic.evidence_items.variant_id6
# civic.evidence_items.variant_id7
# civic.evidence_items.variant_id8
# civic.evidence_items.variant_id9
# civic.evidence_items.variant_origin
# civic.evidence_items.variant_origin1
# civic.evidence_items.variant_origin10
# civic.evidence_items.variant_origin11
# civic.evidence_items.variant_origin12
# civic.evidence_items.variant_origin13
# civic.evidence_items.variant_origin14
# civic.evidence_items.variant_origin15
# civic.evidence_items.variant_origin16
# civic.evidence_items.variant_origin17
# civic.evidence_items.variant_origin18
# civic.evidence_items.variant_origin19
# civic.evidence_items.variant_origin2
# civic.evidence_items.variant_origin20
# civic.evidence_items.variant_origin21
# civic.evidence_items.variant_origin3
# civic.evidence_items.variant_origin4
# civic.evidence_items.variant_origin5
# civic.evidence_items.variant_origin6
# civic.evidence_items.variant_origin7
# civic.evidence_items.variant_origin8
# civic.evidence_items.variant_origin9
# clinvar._license
# clinvar.rcv.accession
# clinvar.rcv.accession1
# clinvar.rcv.accession10
# clinvar.rcv.accession11
# clinvar.rcv.accession12
# clinvar.rcv.accession13
# clinvar.rcv.accession14
# clinvar.rcv.accession15
# clinvar.rcv.accession16
# clinvar.rcv.accession17
# clinvar.rcv.accession18
# clinvar.rcv.accession19
# clinvar.rcv.accession2
# clinvar.rcv.accession20
# clinvar.rcv.accession21
# clinvar.rcv.accession22
# clinvar.rcv.accession23
# clinvar.rcv.accession24
# clinvar.rcv.accession25
# clinvar.rcv.accession26
# clinvar.rcv.accession27
# clinvar.rcv.accession28
# clinvar.rcv.accession29
# clinvar.rcv.accession3
# clinvar.rcv.accession30
# clinvar.rcv.accession31
# clinvar.rcv.accession32
# clinvar.rcv.accession33
# clinvar.rcv.accession4
# clinvar.rcv.accession5
# clinvar.rcv.accession6
# clinvar.rcv.accession7
# clinvar.rcv.accession8
# clinvar.rcv.accession9
# clinvar.rcv.clinical_significance
# clinvar.rcv.clinical_significance1
# clinvar.rcv.clinical_significance10
# clinvar.rcv.clinical_significance11
# clinvar.rcv.clinical_significance12
# clinvar.rcv.clinical_significance13
# clinvar.rcv.clinical_significance14
# clinvar.rcv.clinical_significance15
# clinvar.rcv.clinical_significance16
# clinvar.rcv.clinical_significance17
# clinvar.rcv.clinical_significance18
# clinvar.rcv.clinical_significance19
# clinvar.rcv.clinical_significance2
# clinvar.rcv.clinical_significance20
# clinvar.rcv.clinical_significance21
# clinvar.rcv.clinical_significance22
# clinvar.rcv.clinical_significance23
# clinvar.rcv.clinical_significance24
# clinvar.rcv.clinical_significance25
# clinvar.rcv.clinical_significance26
# clinvar.rcv.clinical_significance27
# clinvar.rcv.clinical_significance28
# clinvar.rcv.clinical_significance29
# clinvar.rcv.clinical_significance3
# clinvar.rcv.clinical_significance30
# clinvar.rcv.clinical_significance31
# clinvar.rcv.clinical_significance32
# clinvar.rcv.clinical_significance33
# clinvar.rcv.clinical_significance4
# clinvar.rcv.clinical_significance5
# clinvar.rcv.clinical_significance6
# clinvar.rcv.clinical_significance7
# clinvar.rcv.clinical_significance8
# clinvar.rcv.clinical_significance9
# clinvar.rcv.conditions.identifiers.medgen
# clinvar.rcv.conditions.identifiers.omim
# clinvar.rcv.conditions.identifiers.orphanet
# clinvar.rcv.conditions.name
# clinvar.rcv.conditions.synonyms
# clinvar.rcv.conditions1.identifiers.gene
# clinvar.rcv.conditions1.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions1.identifiers.medgen
# clinvar.rcv.conditions1.identifiers.mesh
# clinvar.rcv.conditions1.identifiers.omim
# clinvar.rcv.conditions1.identifiers.orphanet
# clinvar.rcv.conditions1.name
# clinvar.rcv.conditions1.synonyms
# clinvar.rcv.conditions10.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions10.identifiers.medgen
# clinvar.rcv.conditions10.identifiers.mesh
# clinvar.rcv.conditions10.identifiers.omim
# clinvar.rcv.conditions10.identifiers.orphanet
# clinvar.rcv.conditions10.name
# clinvar.rcv.conditions10.synonyms
# clinvar.rcv.conditions11.identifiers.gene
# clinvar.rcv.conditions11.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions11.identifiers.medgen
# clinvar.rcv.conditions11.identifiers.mesh
# clinvar.rcv.conditions11.identifiers.omim
# clinvar.rcv.conditions11.identifiers.orphanet
# clinvar.rcv.conditions11.name
# clinvar.rcv.conditions11.synonyms
# clinvar.rcv.conditions12.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions12.identifiers.medgen
# clinvar.rcv.conditions12.identifiers.mesh
# clinvar.rcv.conditions12.identifiers.omim
# clinvar.rcv.conditions12.identifiers.orphanet
# clinvar.rcv.conditions12.name
# clinvar.rcv.conditions12.synonyms
# clinvar.rcv.conditions13.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions13.identifiers.medgen
# clinvar.rcv.conditions13.identifiers.mesh
# clinvar.rcv.conditions13.identifiers.omim
# clinvar.rcv.conditions13.identifiers.orphanet
# clinvar.rcv.conditions13.name
# clinvar.rcv.conditions13.synonyms
# clinvar.rcv.conditions14.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions14.identifiers.medgen
# clinvar.rcv.conditions14.identifiers.mesh
# clinvar.rcv.conditions14.identifiers.omim
# clinvar.rcv.conditions14.identifiers.orphanet
# clinvar.rcv.conditions14.name
# clinvar.rcv.conditions14.synonyms
# clinvar.rcv.conditions15.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions15.identifiers.medgen
# clinvar.rcv.conditions15.identifiers.mesh
# clinvar.rcv.conditions15.name
# clinvar.rcv.conditions15.synonyms
# clinvar.rcv.conditions16.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions16.identifiers.medgen
# clinvar.rcv.conditions16.identifiers.mesh
# clinvar.rcv.conditions16.name
# clinvar.rcv.conditions16.synonyms
# clinvar.rcv.conditions17.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions17.identifiers.medgen
# clinvar.rcv.conditions17.identifiers.mesh
# clinvar.rcv.conditions17.identifiers.omim
# clinvar.rcv.conditions17.identifiers.orphanet
# clinvar.rcv.conditions17.name
# clinvar.rcv.conditions17.synonyms
# clinvar.rcv.conditions18.identifiers.gene
# clinvar.rcv.conditions18.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions18.identifiers.medgen
# clinvar.rcv.conditions18.identifiers.mesh
# clinvar.rcv.conditions18.identifiers.omim
# clinvar.rcv.conditions18.identifiers.orphanet
# clinvar.rcv.conditions18.name
# clinvar.rcv.conditions18.synonyms
# clinvar.rcv.conditions19.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions19.identifiers.medgen
# clinvar.rcv.conditions19.identifiers.mesh
# clinvar.rcv.conditions19.identifiers.omim
# clinvar.rcv.conditions19.identifiers.orphanet
# clinvar.rcv.conditions19.name
# clinvar.rcv.conditions19.synonyms
# clinvar.rcv.conditions2.identifiers.gene
# clinvar.rcv.conditions2.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions2.identifiers.medgen
# clinvar.rcv.conditions2.identifiers.mesh
# clinvar.rcv.conditions2.identifiers.omim
# clinvar.rcv.conditions2.identifiers.orphanet
# clinvar.rcv.conditions2.name
# clinvar.rcv.conditions2.synonyms
# clinvar.rcv.conditions20.identifiers.gene
# clinvar.rcv.conditions20.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions20.identifiers.medgen
# clinvar.rcv.conditions20.identifiers.mesh
# clinvar.rcv.conditions20.identifiers.omim
# clinvar.rcv.conditions20.name
# clinvar.rcv.conditions20.synonyms
# clinvar.rcv.conditions21.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions21.identifiers.medgen
# clinvar.rcv.conditions21.identifiers.mesh
# clinvar.rcv.conditions21.identifiers.omim
# clinvar.rcv.conditions21.name
# clinvar.rcv.conditions21.synonyms
# clinvar.rcv.conditions22.identifiers.medgen
# clinvar.rcv.conditions22.identifiers.mesh
# clinvar.rcv.conditions22.name
# clinvar.rcv.conditions23.identifiers.gene
# clinvar.rcv.conditions23.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions23.identifiers.medgen
# clinvar.rcv.conditions23.identifiers.mesh
# clinvar.rcv.conditions23.identifiers.omim
# clinvar.rcv.conditions23.identifiers.orphanet
# clinvar.rcv.conditions23.name
# clinvar.rcv.conditions23.synonyms
# clinvar.rcv.conditions24.identifiers.medgen
# clinvar.rcv.conditions24.identifiers.omim
# clinvar.rcv.conditions24.name
# clinvar.rcv.conditions24.synonyms
# clinvar.rcv.conditions25.identifiers.medgen
# clinvar.rcv.conditions25.name
# clinvar.rcv.conditions26.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions26.identifiers.medgen
# clinvar.rcv.conditions26.identifiers.mesh
# clinvar.rcv.conditions26.name
# clinvar.rcv.conditions27.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions27.identifiers.medgen
# clinvar.rcv.conditions27.identifiers.mesh
# clinvar.rcv.conditions27.name
# clinvar.rcv.conditions27.synonyms
# clinvar.rcv.conditions28.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions28.identifiers.medgen
# clinvar.rcv.conditions28.identifiers.mesh
# clinvar.rcv.conditions28.name
# clinvar.rcv.conditions28.synonyms
# clinvar.rcv.conditions29.identifiers.medgen
# clinvar.rcv.conditions29.name
# clinvar.rcv.conditions3.identifiers.gene
# clinvar.rcv.conditions3.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions3.identifiers.medgen
# clinvar.rcv.conditions3.identifiers.mesh
# clinvar.rcv.conditions3.identifiers.omim
# clinvar.rcv.conditions3.identifiers.orphanet
# clinvar.rcv.conditions3.name
# clinvar.rcv.conditions3.synonyms
# clinvar.rcv.conditions30.identifiers.medgen
# clinvar.rcv.conditions30.name
# clinvar.rcv.conditions31.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions31.identifiers.medgen
# clinvar.rcv.conditions31.name
# clinvar.rcv.conditions32.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions32.identifiers.medgen
# clinvar.rcv.conditions32.identifiers.mesh
# clinvar.rcv.conditions32.name
# clinvar.rcv.conditions32.synonyms
# clinvar.rcv.conditions33.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions33.identifiers.medgen
# clinvar.rcv.conditions33.identifiers.mesh
# clinvar.rcv.conditions33.name
# clinvar.rcv.conditions33.synonyms
# clinvar.rcv.conditions4.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions4.identifiers.medgen
# clinvar.rcv.conditions4.identifiers.mesh
# clinvar.rcv.conditions4.identifiers.omim
# clinvar.rcv.conditions4.identifiers.orphanet
# clinvar.rcv.conditions4.name
# clinvar.rcv.conditions4.synonyms
# clinvar.rcv.conditions5.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions5.identifiers.medgen
# clinvar.rcv.conditions5.identifiers.mesh
# clinvar.rcv.conditions5.identifiers.omim
# clinvar.rcv.conditions5.identifiers.orphanet
# clinvar.rcv.conditions5.name
# clinvar.rcv.conditions5.synonyms
# clinvar.rcv.conditions6
# clinvar.rcv.conditions6.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions6.identifiers.medgen
# clinvar.rcv.conditions6.identifiers.mesh
# clinvar.rcv.conditions6.identifiers.omim
# clinvar.rcv.conditions6.identifiers.orphanet
# clinvar.rcv.conditions6.name
# clinvar.rcv.conditions6.synonyms
# clinvar.rcv.conditions7.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions7.identifiers.medgen
# clinvar.rcv.conditions7.identifiers.mesh
# clinvar.rcv.conditions7.identifiers.omim
# clinvar.rcv.conditions7.identifiers.orphanet
# clinvar.rcv.conditions7.name
# clinvar.rcv.conditions7.synonyms
# clinvar.rcv.conditions8.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions8.identifiers.medgen
# clinvar.rcv.conditions8.identifiers.mesh
# clinvar.rcv.conditions8.identifiers.omim
# clinvar.rcv.conditions8.identifiers.orphanet
# clinvar.rcv.conditions8.name
# clinvar.rcv.conditions8.synonyms
# clinvar.rcv.conditions9.identifiers.human_phenotype_ontology
# clinvar.rcv.conditions9.identifiers.medgen
# clinvar.rcv.conditions9.identifiers.mesh
# clinvar.rcv.conditions9.identifiers.omim
# clinvar.rcv.conditions9.identifiers.orphanet
# clinvar.rcv.conditions9.name
# clinvar.rcv.conditions9.synonyms
# cosmic._license
# cosmic.cosmic_id
# cosmic.tumor_site
# dbsnp._license
# exonicfunc_knowngene
# genedetail_knowngene
# gwassnps._license
# gwassnps.genename
# gwassnps.pubmed
# gwassnps.pvalue
# gwassnps.pvalue_desc
# gwassnps.region
# gwassnps.risk_allele
# gwassnps.risk_allele_freq
# gwassnps.rsid
# gwassnps.title
# gwassnps.trait
# hgvs_id
# notfound
# samples.filter_passing_reads_count
# samples.genotype
# wellderly._license
# wellderly.alleles.allele1
# wellderly.alleles.allele2
# wellderly.alleles.allele3
# wellderly.alleles.freq1
# wellderly.alleles.freq2
# wellderly.alleles.freq3

# %%
myDf.to_csv('all_variants.maf',  sep= "\t", index=False)

# %% [markdown]
# # Debugging/Testing

# %% [markdown]
# ### Original format

# %%
df = pd.DataFrame(data=rare_deleterious_variants)
df
# Out:
#     1000g2015aug_all                       _id alt  \
# 0           0.022764  5b7222622c788e54da746c5e   T
# 1           0.001398  5b7222622c788e54da746c79   T
# 2           0.005391  5b7222632c788e54d4747089   T
# 3           0.002396  5b7222632c788e54d47470a0   T
# 4           0.015974  5b7222632c788e54d5746cd0   A
# 5           0.041933  5b7222632c788e54d5746d03   T
# 6           0.000200  5b7222632c788e54d5747094   A
# 7           0.008387  5b7222632c788e54d3746eda   A
# 8           0.000200  5b7222642c788e54d8746d0e   A
# 9           0.021566  5b7222642c788e54d8746fdf   T
# 10          0.050719  5b7222642c788e54d874700c   T
# 11          0.016574  5b7222642c788e54d8747086   T
# 12          0.000200  5b7222642c788e54d7746d68   T
# 13          0.013978  5b7222642c788e54d7746f25   T
# 14          0.012780  5b7222642c788e54d9746d02   C
#
#                                                  cadd chr  \
# 0   {'1000g': {'af': 0.04, 'afr': 0.002, 'amr': 0....   9
# 1   {'1000g': {'af': 0.001, 'amr': 0.01}, '_licens...   9
# 2   {'1000g': {'af': 0.01, 'afr': 0.004, 'amr': 0....   1
# 3   {'1000g': {'af': 0.003, 'afr': 0.01}, '_licens...   1
# 4   {'1000g': {'af': 0.03, 'afr': 0.004, 'amr': 0....  16
# 5   {'1000g': {'af': 0.05, 'afr': 0.02, 'amr': 0.0...  16
# 6   {'1000g': {'af': 0.001, 'eur': 0.001}, '_licen...  19
# 7   {'1000g': {'af': 0.01, 'afr': 0.01, 'amr': 0.0...  14
# 8   {'_license': 'http://goo.gl/bkpNhq', 'gerp': {...   4
# 9   {'1000g': {'af': 0.03, 'afr': 0.01, 'amr': 0.0...   6
# 10  {'1000g': {'af': 0.03, 'afr': 0.004, 'amr': 0....   6
# 11  {'1000g': {'af': 0.02, 'afr': 0.01, 'amr': 0.0...   6
# 12  {'_license': 'http://goo.gl/bkpNhq', 'gerp': {...  22
# 13  {'1000g': {'af': 0.02, 'afr': 0.01, 'amr': 0.0...   3
# 14  {'1000g': {'af': 0.02, 'afr': 0.002, 'amr': 0....   7
#
#                                               clinvar  \
# 0                                                 NaN
# 1   {'_license': 'https://goo.gl/OaHML9', 'rcv': [...
# 2                                                 NaN
# 3                                                 NaN
# 4   {'_license': 'https://goo.gl/OaHML9', 'rcv': [...
# 5   {'_license': 'https://goo.gl/OaHML9', 'rcv': [...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'_license': 'https://goo.gl/OaHML9', 'rcv': {...
#
#                                                cosmic  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'_license': 'https://goo.gl/2tibWa', 'cosmic_...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'_license': 'https://goo.gl/2tibWa', 'cosmic_...
# 13                                                NaN
# 14                                                NaN
#
#                                                 dbsnp        end  \
# 0   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  138377498
# 1   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  139405649
# 2   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  152280110
# 3   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  152281795
# 4   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   89838086
# 5   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   89883007
# 6   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...    1036460
# 7   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   24803710
# 8   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  187627812
# 9   {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   27834677
# 10  {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   29797420
# 11  {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   31238179
# 12                                                NaN   19230452
# 13  {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...   40503506
# 14  {'_license': 'https://goo.gl/Ztr5rl', 'rsid': ...  151949735
#
#    exonicfunc_knowngene func_knowngene gene_knowngene              hgvs_id  \
# 0     nonsynonymous SNV         exonic        PPP1R26  chr9:g.138377498G>T
# 1     nonsynonymous SNV         exonic         NOTCH1  chr9:g.139405649C>T
# 2     nonsynonymous SNV         exonic            FLG  chr1:g.152280110C>T
# 3     nonsynonymous SNV         exonic            FLG  chr1:g.152281795C>T
# 4     nonsynonymous SNV         exonic          FANCA  chr16:g.89838086C>A
# 5     nonsynonymous SNV         exonic          FANCA  chr16:g.89883007A>T
# 6     nonsynonymous SNV         exonic           CNN2   chr19:g.1036460G>A
# 7     nonsynonymous SNV         exonic          ADCY4  chr14:g.24803710G>A
# 8     nonsynonymous SNV         exonic           FAT1  chr4:g.187627812G>A
# 9     nonsynonymous SNV         exonic       HIST1H1B   chr6:g.27834677C>T
# 10    nonsynonymous SNV         exonic          HLA-G   chr6:g.29797420C>T
# 11    nonsynonymous SNV         exonic          HLA-C   chr6:g.31238179C>T
# 12    nonsynonymous SNV         exonic         CLTCL1  chr22:g.19230452C>T
# 13    nonsynonymous SNV         exonic          RPL14   chr3:g.40503506C>T
# 14    nonsynonymous SNV         exonic          KMT2C  chr7:g.151949735T>C
#
#    ref                                            samples      start  \
# 0    G  [{'sample_id': 'N7_vs_T7', 'genotype': None, '...  138377498
# 1    C  [{'sample_id': 'N7_vs_T7', 'genotype': None, '...  139405649
# 2    C  [{'sample_id': 'N39_vs_T39', 'genotype': None,...  152280110
# 3    C  [{'sample_id': 'N9_vs_T9', 'genotype': None, '...  152281795
# 4    C  [{'sample_id': 'N39_vs_T39', 'genotype': None,...   89838086
# 5    A  [{'sample_id': 'N39_vs_T39', 'genotype': None,...   89883007
# 6    G  [{'sample_id': 'N44_vs_T44', 'genotype': None,...    1036460
# 7    G  [{'sample_id': 'N7_vs_T7', 'genotype': None, '...   24803710
# 8    G  [{'sample_id': 'N44_vs_T44', 'genotype': None,...  187627812
# 9    C  [{'sample_id': 'N39_vs_T39', 'genotype': None,...   27834677
# 10   C  [{'sample_id': 'N7_vs_T7', 'genotype': None, '...   29797420
# 11   C  [{'sample_id': 'N39_vs_T39', 'genotype': None,...   31238179
# 12   C  [{'sample_id': 'N15_vs_T15', 'genotype': None,...   19230452
# 13   C  [{'sample_id': 'N7_vs_T7', 'genotype': None, '...   40503506
# 14   T  [{'sample_id': 'N39_vs_T39', 'genotype': None,...  151949735
#
#                                             wellderly
# 0   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 1                                                 NaN
# 2   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 3   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 4   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 5   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 6                                                 NaN
# 7   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 8                                                 NaN
# 9   {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 10  {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 11  {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 12                                                NaN
# 13  {'_license': 'https://goo.gl/e8OO17', 'alleles...
# 14  {'_license': 'https://goo.gl/e8OO17', 'alleles...

# %%
df_k = pd.DataFrame(data=known_disease_variants)
for x in range(len(df_k.samples)):
    print(df_k.samples[x])
# Out:
# [{'sample_id': 'N40_vs_T40', 'genotype': None, 'filter_passing_reads_count': 263, 'AD': [263, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 88, 'AD': [88, 0]}]
# [{'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 102, 'AD': [102, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 71, 'AD': [71, 0]}]
# [{'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 106, 'AD': [106, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 118, 'AD': [118, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 542, 'AD': [542, 0]}]
# [{'sample_id': 'N17_vs_T17', 'genotype': None, 'filter_passing_reads_count': 146, 'AD': [146, 0]}, {'sample_id': 'N1_vs_T1', 'genotype': None, 'filter_passing_reads_count': 136, 'AD': [136, 0]}]
# [{'sample_id': 'N17_vs_T17', 'genotype': None, 'filter_passing_reads_count': 146, 'AD': [146, 0]}, {'sample_id': 'N1_vs_T1', 'genotype': None, 'filter_passing_reads_count': 136, 'AD': [136, 0]}]
# [{'sample_id': 'N36_vs_T36', 'genotype': None, 'filter_passing_reads_count': 10, 'AD': [11, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 242, 'AD': [242, 0]}, {'sample_id': 'N9_vs_T9', 'genotype': None, 'filter_passing_reads_count': 381, 'AD': [380, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 87, 'AD': [87, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 27, 'AD': [27, 0]}]
# [{'sample_id': 'N32_vs_T32', 'genotype': None, 'filter_passing_reads_count': 11, 'AD': [11, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 29, 'AD': [29, 0]}]
# [{'sample_id': 'N43_vs_T43', 'genotype': None, 'filter_passing_reads_count': 13, 'AD': [13, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 146, 'AD': [146, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 400, 'AD': [399, 1]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 212, 'AD': [361, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 212, 'AD': [212, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 412, 'AD': [422, 0]}]
# [{'sample_id': 'N9_vs_T9', 'genotype': None, 'filter_passing_reads_count': 410, 'AD': [409, 1]}]
# [{'sample_id': 'N12_vs_T12', 'genotype': None, 'filter_passing_reads_count': 393, 'AD': [392, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 389, 'AD': [389, 0]}]
# [{'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 461, 'AD': [461, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 216, 'AD': [216, 0]}]
# [{'sample_id': 'N3_vs_T3', 'genotype': None, 'filter_passing_reads_count': 197, 'AD': [197, 0]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 42, 'AD': [41, 1]}, {'sample_id': 'N31_vs_T31', 'genotype': None, 'filter_passing_reads_count': 98, 'AD': [97, 1]}, {'sample_id': 'N34_vs_T34', 'genotype': None, 'filter_passing_reads_count': 41, 'AD': [40, 1]}, {'sample_id': 'N3_vs_T3', 'genotype': None, 'filter_passing_reads_count': 39, 'AD': [38, 1]}]
# [{'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 79, 'AD': [79, 0]}, {'sample_id': 'N5_vs_T5', 'genotype': None, 'filter_passing_reads_count': 48, 'AD': [47, 1]}]
# [{'sample_id': 'N16_vs_T16', 'genotype': None, 'filter_passing_reads_count': 56, 'AD': [56, 1]}, {'sample_id': 'N30_vs_T30', 'genotype': None, 'filter_passing_reads_count': 68, 'AD': [67, 1]}, {'sample_id': 'N49_vs_T49', 'genotype': None, 'filter_passing_reads_count': 50, 'AD': [49, 1]}, {'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 58, 'AD': [58, 0]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 19, 'AD': [19, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 31, 'AD': [31, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 45, 'AD': [45, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 51, 'AD': [51, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 8, 'AD': [8, 0]}]
# [{'sample_id': 'N10_vs_T10', 'genotype': None, 'filter_passing_reads_count': 257, 'AD': [257, 0]}]
# [{'sample_id': 'N16_vs_T16', 'genotype': None, 'filter_passing_reads_count': 348, 'AD': [351, 0]}]
# [{'sample_id': 'N17_vs_T17', 'genotype': None, 'filter_passing_reads_count': 78, 'AD': [78, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 364, 'AD': [363, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 20, 'AD': [20, 0]}]
# [{'sample_id': 'N16_vs_T16', 'genotype': None, 'filter_passing_reads_count': 39, 'AD': [38, 1]}, {'sample_id': 'N25_vs_T25', 'genotype': None, 'filter_passing_reads_count': 45, 'AD': [45, 0]}, {'sample_id': 'N45_vs_T45', 'genotype': None, 'filter_passing_reads_count': 59, 'AD': [57, 1]}, {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 63, 'AD': [63, 0]}]
# [{'sample_id': 'N16_vs_T16', 'genotype': None, 'filter_passing_reads_count': 45, 'AD': [45, 0]}, {'sample_id': 'N46_vs_T46', 'genotype': None, 'filter_passing_reads_count': 38, 'AD': [38, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 128, 'AD': [128, 0]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 70, 'AD': [70, 0]}]
# [{'sample_id': 'N3_vs_T3', 'genotype': None, 'filter_passing_reads_count': 235, 'AD': [235, 0]}]
# [{'sample_id': 'N47_vs_T47', 'genotype': None, 'filter_passing_reads_count': 421, 'AD': [420, 1]}]
# [{'sample_id': 'N2_vs_T2', 'genotype': None, 'filter_passing_reads_count': 306, 'AD': [306, 0]}, {'sample_id': 'N30_vs_T30', 'genotype': None, 'filter_passing_reads_count': 391, 'AD': [390, 0]}]
# [{'sample_id': 'N2_vs_T2', 'genotype': None, 'filter_passing_reads_count': 306, 'AD': [306, 0]}, {'sample_id': 'N30_vs_T30', 'genotype': None, 'filter_passing_reads_count': 391, 'AD': [390, 0]}]
# [{'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 439, 'AD': [439, 0]}]
# [{'sample_id': 'N45_vs_T45', 'genotype': None, 'filter_passing_reads_count': 326, 'AD': [326, 0]}]
# [{'sample_id': 'N35_vs_T35', 'genotype': None, 'filter_passing_reads_count': 535, 'AD': [535, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 407, 'AD': [404, 1]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 388, 'AD': [387, 1]}]
# [{'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 490, 'AD': [490, 0]}]
# [{'sample_id': 'N34_vs_T34', 'genotype': None, 'filter_passing_reads_count': 258, 'AD': [257, 1]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 31, 'AD': [30, 1]}]
# [{'sample_id': 'N32_vs_T32', 'genotype': None, 'filter_passing_reads_count': 39, 'AD': [38, 1]}]
# [{'sample_id': 'N45_vs_T45', 'genotype': None, 'filter_passing_reads_count': 183, 'AD': [183, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 53, 'AD': [52, 1]}]
# [{'sample_id': 'N15_vs_T15', 'genotype': None, 'filter_passing_reads_count': 368, 'AD': [368, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 352, 'AD': [352, 0]}]
# [{'sample_id': 'N8_vs_T8', 'genotype': None, 'filter_passing_reads_count': 407, 'AD': [407, 0]}]
# [{'sample_id': 'N33_vs_T33', 'genotype': None, 'filter_passing_reads_count': 218, 'AD': [223, 0]}, {'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 336, 'AD': [342, 0]}]
# [{'sample_id': 'N12_vs_T12', 'genotype': None, 'filter_passing_reads_count': 232, 'AD': [232, 0]}, {'sample_id': 'N14_vs_T14', 'genotype': None, 'filter_passing_reads_count': 290, 'AD': [290, 0]}, {'sample_id': 'N1_vs_T1', 'genotype': None, 'filter_passing_reads_count': 186, 'AD': [186, 0]}, {'sample_id': 'N2_vs_T2', 'genotype': None, 'filter_passing_reads_count': 173, 'AD': [172, 0]}, {'sample_id': 'N30_vs_T30', 'genotype': None, 'filter_passing_reads_count': 209, 'AD': [209, 0]}, {'sample_id': 'N31_vs_T31', 'genotype': None, 'filter_passing_reads_count': 314, 'AD': [315, 0]}, {'sample_id': 'N36_vs_T36', 'genotype': None, 'filter_passing_reads_count': 145, 'AD': [145, 0]}, {'sample_id': 'N41_vs_T41', 'genotype': None, 'filter_passing_reads_count': 268, 'AD': [268, 0]}]
# [{'sample_id': 'N38_vs_T38', 'genotype': None, 'filter_passing_reads_count': 481, 'AD': [481, 0]}]
# [{'sample_id': 'N10_vs_T10', 'genotype': None, 'filter_passing_reads_count': 79, 'AD': [79, 0]}, {'sample_id': 'N28_vs_T28', 'genotype': None, 'filter_passing_reads_count': 146, 'AD': [146, 0]}, {'sample_id': 'N38_vs_T38', 'genotype': None, 'filter_passing_reads_count': 86, 'AD': [86, 0]}, {'sample_id': 'N41_vs_T41', 'genotype': None, 'filter_passing_reads_count': 77, 'AD': [77, 0]}, {'sample_id': 'N4_vs_T4', 'genotype': None, 'filter_passing_reads_count': 102, 'AD': [101, 0]}, {'sample_id': 'N6_vs_T6', 'genotype': None, 'filter_passing_reads_count': 199, 'AD': [199, 0]}]
# [{'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 90, 'AD': [90, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 340, 'AD': [340, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 574, 'AD': [581, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 550, 'AD': [550, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 427, 'AD': [576, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 585, 'AD': [599, 1]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 537, 'AD': [538, 1]}]
# [{'sample_id': 'N6_vs_T6', 'genotype': None, 'filter_passing_reads_count': 120, 'AD': [118, 1]}]
# [{'sample_id': 'N17_vs_T17', 'genotype': None, 'filter_passing_reads_count': 53, 'AD': [53, 0]}]
# [{'sample_id': 'N17_vs_T17', 'genotype': None, 'filter_passing_reads_count': 51, 'AD': [50, 1]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 57, 'AD': [57, 0]}]
# [{'sample_id': 'N18_vs_T18', 'genotype': None, 'filter_passing_reads_count': 260, 'AD': [260, 0]}]
# [{'sample_id': 'N30_vs_T30', 'genotype': None, 'filter_passing_reads_count': 382, 'AD': [382, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 65, 'AD': [65, 0]}]

# %% [markdown]
# ### Extract samples

# %%
myList = extract_samples(rare_deleterious_variants)

# %%
for x in range(len(rare_deleterious_variants)):
    print(rare_deleterious_variants[x]['samples'])
# Out:
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 75, 'AD': [75, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 276, 'AD': [276, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 322, 'AD': [398, 0]}]
# [{'sample_id': 'N9_vs_T9', 'genotype': None, 'filter_passing_reads_count': 410, 'AD': [409, 1]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 337, 'AD': [337, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 25, 'AD': [25, 0]}]
# [{'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 36, 'AD': [36, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 292, 'AD': [292, 0]}]
# [{'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 242, 'AD': [242, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 138, 'AD': [138, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 128, 'AD': [129, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 138, 'AD': [142, 0]}]
# [{'sample_id': 'N15_vs_T15', 'genotype': None, 'filter_passing_reads_count': 368, 'AD': [368, 0]}]
# [{'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 34, 'AD': [38, 0]}]
# [{'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 290, 'AD': [289, 0]}]

# %%
for x in range(len(myList)):
    print(myList[x]['samples'])
# Out:
# {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 75, 'AD': [75, 0]}
# {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 276, 'AD': [276, 0]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 322, 'AD': [398, 0]}
# {'sample_id': 'N9_vs_T9', 'genotype': None, 'filter_passing_reads_count': 410, 'AD': [409, 1]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 337, 'AD': [337, 0]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 25, 'AD': [25, 0]}
# {'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 36, 'AD': [36, 0]}
# {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 292, 'AD': [292, 0]}
# {'sample_id': 'N44_vs_T44', 'genotype': None, 'filter_passing_reads_count': 242, 'AD': [242, 0]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 138, 'AD': [138, 0]}
# {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 128, 'AD': [129, 0]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 138, 'AD': [142, 0]}
# {'sample_id': 'N15_vs_T15', 'genotype': None, 'filter_passing_reads_count': 368, 'AD': [368, 0]}
# {'sample_id': 'N7_vs_T7', 'genotype': None, 'filter_passing_reads_count': 34, 'AD': [38, 0]}
# {'sample_id': 'N39_vs_T39', 'genotype': None, 'filter_passing_reads_count': 290, 'AD': [289, 0]}

# %% [markdown]
# ### Annotation keys

# %%
a = list(rare_deleterious_variants[0].keys())
for key in a:
    print(key)
# Out:
# _id
# chr
# start
# end
# ref
# alt
# func_knowngene
# gene_knowngene
# exonicfunc_knowngene
# 1000g2015aug_all
# hgvs_id
# samples
# cadd
# dbsnp
# wellderly

# %%
print(type(rare_deleterious_variants[14]['wellderly']['alleles']))
print(rare_deleterious_variants[14]['wellderly']['alleles'])
# Out:
# <class 'list'>
# [{'allele': 'C', 'freq': 0.0325}, {'allele': 'T', 'freq': 0.9675}]

# %% [markdown]
# ### Unnest dictionaries

# %%
myList2 = unnest_dict(myList)
df2 = pd.DataFrame(data=myList2)
df2
# Out:
#     1000g2015aug_all                       _id alt  cadd.1000g.af  \
# 0           0.022764  5b7222622c788e54da746c5e   T          0.040
# 1           0.001398  5b7222622c788e54da746c79   T          0.001
# 2           0.005391  5b7222632c788e54d4747089   T          0.010
# 3           0.002396  5b7222632c788e54d47470a0   T          0.003
# 4           0.015974  5b7222632c788e54d5746cd0   A          0.030
# 5           0.041933  5b7222632c788e54d5746d03   T          0.050
# 6           0.000200  5b7222632c788e54d5747094   A          0.001
# 7           0.008387  5b7222632c788e54d3746eda   A          0.010
# 8           0.000200  5b7222642c788e54d8746d0e   A            NaN
# 9           0.021566  5b7222642c788e54d8746fdf   T          0.030
# 10          0.050719  5b7222642c788e54d874700c   T          0.030
# 11          0.016574  5b7222642c788e54d8747086   T          0.020
# 12          0.000200  5b7222642c788e54d7746d68   T            NaN
# 13          0.013978  5b7222642c788e54d7746f25   T          0.020
# 14          0.012780  5b7222642c788e54d9746d02   C          0.020
#
#     cadd.1000g.afr  cadd.1000g.amr  cadd.1000g.asn  cadd.1000g.eur  \
# 0            0.002            0.05             NaN           0.080
# 1              NaN            0.01             NaN             NaN
# 2            0.004            0.01             NaN           0.020
# 3            0.010             NaN             NaN             NaN
# 4            0.004            0.07             NaN           0.040
# 5            0.020            0.06           0.004           0.100
# 6              NaN             NaN             NaN           0.001
# 7            0.010            0.01             NaN           0.030
# 8              NaN             NaN             NaN             NaN
# 9            0.010            0.02           0.002           0.060
# 10           0.004            0.03           0.010           0.050
# 11           0.010            0.01           0.002           0.040
# 12             NaN             NaN             NaN             NaN
# 13           0.010            0.02             NaN           0.040
# 14           0.002            0.02             NaN           0.050
#
#            cadd._license  cadd.esp.af  \
# 0   http://goo.gl/bkpNhq        0.048
# 1   http://goo.gl/bkpNhq        0.003
# 2   http://goo.gl/bkpNhq        0.014
# 3   http://goo.gl/bkpNhq        0.002
# 4   http://goo.gl/bkpNhq        0.022
# 5   http://goo.gl/bkpNhq        0.050
# 6   http://goo.gl/bkpNhq          NaN
# 7   http://goo.gl/bkpNhq        0.015
# 8   http://goo.gl/bkpNhq          NaN
# 9   http://goo.gl/bkpNhq        0.039
# 10  http://goo.gl/bkpNhq        0.047
# 11  http://goo.gl/bkpNhq        0.030
# 12  http://goo.gl/bkpNhq          NaN
# 13  http://goo.gl/bkpNhq        0.029
# 14  http://goo.gl/bkpNhq        0.031
#
#                           ...                          gene_knowngene  \
# 0                         ...                                 PPP1R26
# 1                         ...                                  NOTCH1
# 2                         ...                                     FLG
# 3                         ...                                     FLG
# 4                         ...                                   FANCA
# 5                         ...                                   FANCA
# 6                         ...                                    CNN2
# 7                         ...                                   ADCY4
# 8                         ...                                    FAT1
# 9                         ...                                HIST1H1B
# 10                        ...                                   HLA-G
# 11                        ...                                   HLA-C
# 12                        ...                                  CLTCL1
# 13                        ...                                   RPL14
# 14                        ...                                   KMT2C
#
#                 hgvs_id  ref  samples.AD  samples.filter_passing_reads_count  \
# 0   chr9:g.138377498G>T    G     [75, 0]                                  75
# 1   chr9:g.139405649C>T    C    [276, 0]                                 276
# 2   chr1:g.152280110C>T    C    [398, 0]                                 322
# 3   chr1:g.152281795C>T    C    [409, 1]                                 410
# 4   chr16:g.89838086C>A    C    [337, 0]                                 337
# 5   chr16:g.89883007A>T    A     [25, 0]                                  25
# 6    chr19:g.1036460G>A    G     [36, 0]                                  36
# 7   chr14:g.24803710G>A    G    [292, 0]                                 292
# 8   chr4:g.187627812G>A    G    [242, 0]                                 242
# 9    chr6:g.27834677C>T    C    [138, 0]                                 138
# 10   chr6:g.29797420C>T    C    [129, 0]                                 128
# 11   chr6:g.31238179C>T    C    [142, 0]                                 138
# 12  chr22:g.19230452C>T    C    [368, 0]                                 368
# 13   chr3:g.40503506C>T    C     [38, 0]                                  34
# 14  chr7:g.151949735T>C    T    [289, 0]                                 290
#
#     samples.genotype  samples.sample_id      start     wellderly._license  \
# 0               None           N7_vs_T7  138377498  https://goo.gl/e8OO17
# 1               None           N7_vs_T7  139405649                    NaN
# 2               None         N39_vs_T39  152280110  https://goo.gl/e8OO17
# 3               None           N9_vs_T9  152281795  https://goo.gl/e8OO17
# 4               None         N39_vs_T39   89838086  https://goo.gl/e8OO17
# 5               None         N39_vs_T39   89883007  https://goo.gl/e8OO17
# 6               None         N44_vs_T44    1036460                    NaN
# 7               None           N7_vs_T7   24803710  https://goo.gl/e8OO17
# 8               None         N44_vs_T44  187627812                    NaN
# 9               None         N39_vs_T39   27834677  https://goo.gl/e8OO17
# 10              None           N7_vs_T7   29797420  https://goo.gl/e8OO17
# 11              None         N39_vs_T39   31238179  https://goo.gl/e8OO17
# 12              None         N15_vs_T15   19230452                    NaN
# 13              None           N7_vs_T7   40503506  https://goo.gl/e8OO17
# 14              None         N39_vs_T39  151949735  https://goo.gl/e8OO17
#
#                                     wellderly.alleles
# 0   [{'allele': 'T', 'freq': 0.0575}, {'allele': '...
# 1                                                 NaN
# 2   [{'allele': 'C', 'freq': 0.98}, {'allele': 'T'...
# 3   [{'allele': 'C', 'freq': 0.9975}, {'allele': '...
# 4   [{'allele': 'A', 'freq': 0.03}, {'allele': 'C'...
# 5   [{'allele': 'A', 'freq': 0.9175}, {'allele': '...
# 6                                                 NaN
# 7   [{'allele': 'A', 'freq': 0.025}, {'allele': 'G...
# 8                                                 NaN
# 9   [{'allele': 'C', 'freq': 0.94}, {'allele': 'T'...
# 10  [{'allele': 'C', 'freq': 0.9125}, {'allele': '...
# 11  [{'allele': 'C', 'freq': 0.9925}, {'allele': '...
# 12                                                NaN
# 13  [{'allele': 'C', 'freq': 0.955}, {'allele': 'T...
# 14  [{'allele': 'C', 'freq': 0.0325}, {'allele': '...
#
# [15 rows x 47 columns]

# %%
myList2[5]
# Out:
# {'_id': ObjectId('5b7222632c788e54d5746d03'),
#  'chr': '16',
#  'start': 89883007,
#  'end': 89883007,
#  'ref': 'A',
#  'alt': 'T',
#  'func_knowngene': 'exonic',
#  'gene_knowngene': 'FANCA',
#  'exonicfunc_knowngene': 'nonsynonymous SNV',
#  '1000g2015aug_all': 0.0419329,
#  'hgvs_id': 'chr16:g.89883007A>T',
#  'samples.sample_id': 'N39_vs_T39',
#  'samples.genotype': None,
#  'samples.filter_passing_reads_count': 25,
#  'samples.AD': [25, 0],
#  'cadd.1000g.af': 0.05,
#  'cadd.1000g.afr': 0.02,
#  'cadd.1000g.amr': 0.06,
#  'cadd.1000g.asn': 0.004,
#  'cadd.1000g.eur': 0.1,
#  'cadd._license': 'http://goo.gl/bkpNhq',
#  'cadd.esp.af': 0.05,
#  'cadd.esp.afr': 0.014,
#  'cadd.esp.eur': 0.066,
#  'cadd.gerp.n': 4.49,
#  'cadd.gerp.s': -2.07,
#  'cadd.phred': 17.1,
#  'cadd.polyphen.cat': 'possibly_damaging',
#  'cadd.polyphen.val': 0.485,
#  'cadd.sift.cat': 'tolerated',
#  'cadd.sift.val': 0.07,
#  'clinvar._license': 'https://goo.gl/OaHML9',
#  'clinvar.rcv': [{'accession': 'RCV000312371',
#    'clinical_significance': 'Likely benign',
#    'conditions': {'identifiers': {'medgen': 'C0015625', 'omim': 'PS227650'},
#     'name': 'Fanconi anemia (FA)',
#     'synonyms': ["Fanconi's anemia"]}},
#   {'accession': 'RCV000120910',
#    'clinical_significance': 'Benign',
#    'conditions': {'identifiers': {'medgen': 'CN169374'},
#     'name': 'not specified',
#     'synonyms': ['AllHighlyPenetrant']}}],
#  'dbsnp._license': 'https://goo.gl/Ztr5rl',
#  'dbsnp.rsid': 'rs1800282',
#  'wellderly._license': 'https://goo.gl/e8OO17',
#  'wellderly.alleles': [{'allele': 'A', 'freq': 0.9175},
#   {'allele': 'T', 'freq': 0.0825}]}

# %% [markdown]
# ### Unnest list

# %%
myList3 = unnest_list(myList2)

# %%
myList3[4]
# Out:
# {'_id': ObjectId('5b7222632c788e54d5746cd0'),
#  'chr': '16',
#  'start': 89838086,
#  'end': 89838086,
#  'ref': 'C',
#  'alt': 'A',
#  'func_knowngene': 'exonic',
#  'gene_knowngene': 'FANCA',
#  'exonicfunc_knowngene': 'nonsynonymous SNV',
#  '1000g2015aug_all': 0.0159744,
#  'hgvs_id': 'chr16:g.89838086C>A',
#  'samples.sample_id': 'N39_vs_T39',
#  'samples.genotype': None,
#  'samples.filter_passing_reads_count': 337,
#  'samples.AD': [337, 0],
#  'cadd.1000g.af': 0.03,
#  'cadd.1000g.afr': 0.004,
#  'cadd.1000g.amr': 0.07,
#  'cadd.1000g.eur': 0.04,
#  'cadd._license': 'http://goo.gl/bkpNhq',
#  'cadd.esp.af': 0.022,
#  'cadd.esp.afr': 0.005,
#  'cadd.esp.eur': 0.031,
#  'cadd.gerp.n': 4.45,
#  'cadd.gerp.s': 3.48,
#  'cadd.phred': 15.03,
#  'cadd.polyphen.cat': 'benign',
#  'cadd.polyphen.val': 0.019,
#  'cadd.sift.cat': 'tolerated',
#  'cadd.sift.val': 0.13,
#  'clinvar._license': 'https://goo.gl/OaHML9',
#  'clinvar.rcv': {'accession1': 'RCV000312324',
#   'clinical_significance1': 'Benign/Likely benign',
#   'conditions1': {'identifiers': {'medgen': 'C0015625', 'omim': 'PS227650'},
#    'name': 'Fanconi anemia (FA)',
#    'synonyms': ["Fanconi's anemia"]},
#   'accession2': 'RCV000120925',
#   'clinical_significance2': 'Benign',
#   'conditions2': {'identifiers': {'medgen': 'CN169374'},
#    'name': 'not specified',
#    'synonyms': ['AllHighlyPenetrant']}},
#  'dbsnp._license': 'https://goo.gl/Ztr5rl',
#  'dbsnp.rsid': 'rs1131660',
#  'wellderly._license': 'https://goo.gl/e8OO17',
#  'wellderly.alleles': {'allele1': 'A',
#   'freq1': 0.03,
#   'allele2': 'C',
#   'freq2': 0.97}}

# %%
myList4 = unnest_dict(myList3)

# %% [markdown]
# ### Chagne 'samples.AD' to 't_ref_count' and 't_alt_count'

# %%
myList5 = samples_AD(myList4)
myList5[6]
# Out:
# {'_id': ObjectId('5b7222632c788e54d5747094'),
#  'chr': '19',
#  'start': 1036460,
#  'end': 1036460,
#  'ref': 'G',
#  'alt': 'A',
#  'func_knowngene': 'exonic',
#  'gene_knowngene': 'CNN2',
#  'exonicfunc_knowngene': 'nonsynonymous SNV',
#  '1000g2015aug_all': 0.000199681,
#  'hgvs_id': 'chr19:g.1036460G>A',
#  'samples.sample_id': 'N44_vs_T44',
#  'samples.genotype': None,
#  'samples.filter_passing_reads_count': 36,
#  't_ref_count': 36,
#  't_alt_count': 0,
#  'cadd.1000g.af': 0.001,
#  'cadd.1000g.eur': 0.001,
#  'cadd._license': 'http://goo.gl/bkpNhq',
#  'cadd.gerp.n': 4.18,
#  'cadd.gerp.rs': 371.9,
#  'cadd.gerp.rs_pval': 8.69202e-66,
#  'cadd.gerp.s': 4.18,
#  'cadd.phred': 24.0,
#  'cadd.polyphen.cat': 'possibly_damaging',
#  'cadd.polyphen.val': 0.723,
#  'cadd.sift.cat': 'tolerated',
#  'cadd.sift.val': 0.06,
#  'dbsnp._license': 'https://goo.gl/Ztr5rl',
#  'dbsnp.rsid': 'rs148071782'}

# %% [markdown]
# ### Record Variant_Type

# %%
myList6 = varType(myList5)

# %% [markdown]
# ### Unnest multiple values separated by ";" in a single field

# %%
myList7 = unnest_semicolon_values(myList6)
df7 = pd.DataFrame(myList7)
df7
# Out:
#     1000g2015aug_all Variant_Type                       _id alt  \
# 0           0.022764          SNP  5b7222622c788e54da746c5e   T
# 1           0.001398          SNP  5b7222622c788e54da746c79   T
# 2           0.005391          SNP  5b7222632c788e54d4747089   T
# 3           0.002396          SNP  5b7222632c788e54d47470a0   T
# 4           0.015974          SNP  5b7222632c788e54d5746cd0   A
# 5           0.041933          SNP  5b7222632c788e54d5746d03   T
# 6           0.000200          SNP  5b7222632c788e54d5747094   A
# 7           0.008387          SNP  5b7222632c788e54d3746eda   A
# 8           0.000200          SNP  5b7222642c788e54d8746d0e   A
# 9           0.021566          SNP  5b7222642c788e54d8746fdf   T
# 10          0.050719          SNP  5b7222642c788e54d874700c   T
# 11          0.016574          SNP  5b7222642c788e54d8747086   T
# 12          0.000200          SNP  5b7222642c788e54d7746d68   T
# 13          0.013978          SNP  5b7222642c788e54d7746f25   T
# 14          0.012780          SNP  5b7222642c788e54d9746d02   C
#
#     cadd.1000g.af  cadd.1000g.afr  cadd.1000g.amr  cadd.1000g.asn  \
# 0           0.040           0.002            0.05             NaN
# 1           0.001             NaN            0.01             NaN
# 2           0.010           0.004            0.01             NaN
# 3           0.003           0.010             NaN             NaN
# 4           0.030           0.004            0.07             NaN
# 5           0.050           0.020            0.06           0.004
# 6           0.001             NaN             NaN             NaN
# 7           0.010           0.010            0.01             NaN
# 8             NaN             NaN             NaN             NaN
# 9           0.030           0.010            0.02           0.002
# 10          0.030           0.004            0.03           0.010
# 11          0.020           0.010            0.01           0.002
# 12            NaN             NaN             NaN             NaN
# 13          0.020           0.010            0.02             NaN
# 14          0.020           0.002            0.02             NaN
#
#     cadd.1000g.eur         cadd._license           ...             \
# 0            0.080  http://goo.gl/bkpNhq           ...
# 1              NaN  http://goo.gl/bkpNhq           ...
# 2            0.020  http://goo.gl/bkpNhq           ...
# 3              NaN  http://goo.gl/bkpNhq           ...
# 4            0.040  http://goo.gl/bkpNhq           ...
# 5            0.100  http://goo.gl/bkpNhq           ...
# 6            0.001  http://goo.gl/bkpNhq           ...
# 7            0.030  http://goo.gl/bkpNhq           ...
# 8              NaN  http://goo.gl/bkpNhq           ...
# 9            0.060  http://goo.gl/bkpNhq           ...
# 10           0.050  http://goo.gl/bkpNhq           ...
# 11           0.040  http://goo.gl/bkpNhq           ...
# 12             NaN  http://goo.gl/bkpNhq           ...
# 13           0.040  http://goo.gl/bkpNhq           ...
# 14           0.050  http://goo.gl/bkpNhq           ...
#
#     samples.genotype  samples.sample_id      start  t_alt_count  t_ref_count  \
# 0               None           N7_vs_T7  138377498            0           75
# 1               None           N7_vs_T7  139405649            0          276
# 2               None         N39_vs_T39  152280110            0          398
# 3               None           N9_vs_T9  152281795            1          409
# 4               None         N39_vs_T39   89838086            0          337
# 5               None         N39_vs_T39   89883007            0           25
# 6               None         N44_vs_T44    1036460            0           36
# 7               None           N7_vs_T7   24803710            0          292
# 8               None         N44_vs_T44  187627812            0          242
# 9               None         N39_vs_T39   27834677            0          138
# 10              None           N7_vs_T7   29797420            0          129
# 11              None         N39_vs_T39   31238179            0          142
# 12              None         N15_vs_T15   19230452            0          368
# 13              None           N7_vs_T7   40503506            0           38
# 14              None         N39_vs_T39  151949735            0          289
#
#        wellderly._license  wellderly.alleles.allele1  \
# 0   https://goo.gl/e8OO17                          T
# 1                     NaN                        NaN
# 2   https://goo.gl/e8OO17                          C
# 3   https://goo.gl/e8OO17                          C
# 4   https://goo.gl/e8OO17                          A
# 5   https://goo.gl/e8OO17                          A
# 6                     NaN                        NaN
# 7   https://goo.gl/e8OO17                          A
# 8                     NaN                        NaN
# 9   https://goo.gl/e8OO17                          C
# 10  https://goo.gl/e8OO17                          C
# 11  https://goo.gl/e8OO17                          C
# 12                    NaN                        NaN
# 13  https://goo.gl/e8OO17                          C
# 14  https://goo.gl/e8OO17                          C
#
#     wellderly.alleles.allele2 wellderly.alleles.freq1  wellderly.alleles.freq2
# 0                           G                  0.0575                   0.9425
# 1                         NaN                     NaN                      NaN
# 2                           T                  0.9800                   0.0200
# 3                           T                  0.9975                   0.0025
# 4                           C                  0.0300                   0.9700
# 5                           T                  0.9175                   0.0825
# 6                         NaN                     NaN                      NaN
# 7                           G                  0.0250                   0.9750
# 8                         NaN                     NaN                      NaN
# 9                           T                  0.9400                   0.0600
# 10                          T                  0.9125                   0.0875
# 11                          T                  0.9925                   0.0075
# 12                        NaN                     NaN                      NaN
# 13                          T                  0.9550                   0.0450
# 14                          T                  0.0325                   0.9675
#
# [15 rows x 72 columns]

# %%
for index, row in df7.iterrows():
    if row['Variant_Classification'] == 'exonic':
        print(row['exonicfunc_knowngene'])

# %%
for key in k6[1].keys():
    print(key + ": ")
    print(k6[1][key])
# Out:
# _id:
# 5b7222622c788e54da746b54
# chr:
# 9
# start:
# 69519038
# end:
# 69519038
# ref:
# G
# alt:
# T
# func_knowngene:
# intergenic
# gene_knowngene:
# BC064148;BC070322
# genedetail_knowngene:
# dist=37363;dist=114311
# hgvs_id:
# chr9:g.69519038G>T
# samples.sample_id:
# N50_vs_T50
# samples.genotype:
# None
# samples.filter_passing_reads_count:
# 10
# t_ref_count:
# 14
# t_alt_count:
# 0
# dbsnp._license:
# https://goo.gl/Ztr5rl
# dbsnp.rsid:
# rs866556502
# Variant_Type:
# SNP

# %% [markdown]
# ### Re-arrange and rename columns

# %%
df4 = pd.DataFrame(data=myList6)
df4
# Out:
#     1000g2015aug_all Variant_Type                       _id alt  \
# 0           0.022764          SNP  5b7222622c788e54da746c5e   T
# 1           0.001398          SNP  5b7222622c788e54da746c79   T
# 2           0.005391          SNP  5b7222632c788e54d4747089   T
# 3           0.002396          SNP  5b7222632c788e54d47470a0   T
# 4           0.015974          SNP  5b7222632c788e54d5746cd0   A
# 5           0.041933          SNP  5b7222632c788e54d5746d03   T
# 6           0.000200          SNP  5b7222632c788e54d5747094   A
# 7           0.008387          SNP  5b7222632c788e54d3746eda   A
# 8           0.000200          SNP  5b7222642c788e54d8746d0e   A
# 9           0.021566          SNP  5b7222642c788e54d8746fdf   T
# 10          0.050719          SNP  5b7222642c788e54d874700c   T
# 11          0.016574          SNP  5b7222642c788e54d8747086   T
# 12          0.000200          SNP  5b7222642c788e54d7746d68   T
# 13          0.013978          SNP  5b7222642c788e54d7746f25   T
# 14          0.012780          SNP  5b7222642c788e54d9746d02   C
#
#     cadd.1000g.af  cadd.1000g.afr  cadd.1000g.amr  cadd.1000g.asn  \
# 0           0.040           0.002            0.05             NaN
# 1           0.001             NaN            0.01             NaN
# 2           0.010           0.004            0.01             NaN
# 3           0.003           0.010             NaN             NaN
# 4           0.030           0.004            0.07             NaN
# 5           0.050           0.020            0.06           0.004
# 6           0.001             NaN             NaN             NaN
# 7           0.010           0.010            0.01             NaN
# 8             NaN             NaN             NaN             NaN
# 9           0.030           0.010            0.02           0.002
# 10          0.030           0.004            0.03           0.010
# 11          0.020           0.010            0.01           0.002
# 12            NaN             NaN             NaN             NaN
# 13          0.020           0.010            0.02             NaN
# 14          0.020           0.002            0.02             NaN
#
#     cadd.1000g.eur         cadd._license           ...             \
# 0            0.080  http://goo.gl/bkpNhq           ...
# 1              NaN  http://goo.gl/bkpNhq           ...
# 2            0.020  http://goo.gl/bkpNhq           ...
# 3              NaN  http://goo.gl/bkpNhq           ...
# 4            0.040  http://goo.gl/bkpNhq           ...
# 5            0.100  http://goo.gl/bkpNhq           ...
# 6            0.001  http://goo.gl/bkpNhq           ...
# 7            0.030  http://goo.gl/bkpNhq           ...
# 8              NaN  http://goo.gl/bkpNhq           ...
# 9            0.060  http://goo.gl/bkpNhq           ...
# 10           0.050  http://goo.gl/bkpNhq           ...
# 11           0.040  http://goo.gl/bkpNhq           ...
# 12             NaN  http://goo.gl/bkpNhq           ...
# 13           0.040  http://goo.gl/bkpNhq           ...
# 14           0.050  http://goo.gl/bkpNhq           ...
#
#     samples.genotype  samples.sample_id      start  t_alt_count  t_ref_count  \
# 0               None           N7_vs_T7  138377498            0           75
# 1               None           N7_vs_T7  139405649            0          276
# 2               None         N39_vs_T39  152280110            0          398
# 3               None           N9_vs_T9  152281795            1          409
# 4               None         N39_vs_T39   89838086            0          337
# 5               None         N39_vs_T39   89883007            0           25
# 6               None         N44_vs_T44    1036460            0           36
# 7               None           N7_vs_T7   24803710            0          292
# 8               None         N44_vs_T44  187627812            0          242
# 9               None         N39_vs_T39   27834677            0          138
# 10              None           N7_vs_T7   29797420            0          129
# 11              None         N39_vs_T39   31238179            0          142
# 12              None         N15_vs_T15   19230452            0          368
# 13              None           N7_vs_T7   40503506            0           38
# 14              None         N39_vs_T39  151949735            0          289
#
#        wellderly._license  wellderly.alleles.allele1  \
# 0   https://goo.gl/e8OO17                          T
# 1                     NaN                        NaN
# 2   https://goo.gl/e8OO17                          C
# 3   https://goo.gl/e8OO17                          C
# 4   https://goo.gl/e8OO17                          A
# 5   https://goo.gl/e8OO17                          A
# 6                     NaN                        NaN
# 7   https://goo.gl/e8OO17                          A
# 8                     NaN                        NaN
# 9   https://goo.gl/e8OO17                          C
# 10  https://goo.gl/e8OO17                          C
# 11  https://goo.gl/e8OO17                          C
# 12                    NaN                        NaN
# 13  https://goo.gl/e8OO17                          C
# 14  https://goo.gl/e8OO17                          C
#
#     wellderly.alleles.allele2 wellderly.alleles.freq1  wellderly.alleles.freq2
# 0                           G                  0.0575                   0.9425
# 1                         NaN                     NaN                      NaN
# 2                           T                  0.9800                   0.0200
# 3                           T                  0.9975                   0.0025
# 4                           C                  0.0300                   0.9700
# 5                           T                  0.9175                   0.0825
# 6                         NaN                     NaN                      NaN
# 7                           G                  0.0250                   0.9750
# 8                         NaN                     NaN                      NaN
# 9                           T                  0.9400                   0.0600
# 10                          T                  0.9125                   0.0875
# 11                          T                  0.9925                   0.0075
# 12                        NaN                     NaN                      NaN
# 13                          T                  0.9550                   0.0450
# 14                          T                  0.0325                   0.9675
#
# [15 rows x 72 columns]

# %%
df4 = change_cols(df4)
df4
# Out:
#    Hugo_Symbol Chromosome  Start_Position  End_Position Reference_Allele  \
# 0      PPP1R26          9       138377498     138377498                G
# 1       NOTCH1          9       139405649     139405649                C
# 2          FLG          1       152280110     152280110                C
# 3          FLG          1       152281795     152281795                C
# 4        FANCA         16        89838086      89838086                C
# 5        FANCA         16        89883007      89883007                A
# 6         CNN2         19         1036460       1036460                G
# 7        ADCY4         14        24803710      24803710                G
# 8         FAT1          4       187627812     187627812                G
# 9     HIST1H1B          6        27834677      27834677                C
# 10       HLA-G          6        29797420      29797420                C
# 11       HLA-C          6        31238179      31238179                C
# 12      CLTCL1         22        19230452      19230452                C
# 13       RPL14          3        40503506      40503506                C
# 14       KMT2C          7       151949735     151949735                T
#
#    Tumor_Seq_Allele2 Variant_Type Variant_Classification Tumor_Sample_Barcode  \
# 0                  T          SNP      Missense_Mutation             N7_vs_T7
# 1                  T          SNP      Missense_Mutation             N7_vs_T7
# 2                  T          SNP      Missense_Mutation           N39_vs_T39
# 3                  T          SNP      Missense_Mutation             N9_vs_T9
# 4                  A          SNP      Missense_Mutation           N39_vs_T39
# 5                  T          SNP      Missense_Mutation           N39_vs_T39
# 6                  A          SNP      Missense_Mutation           N44_vs_T44
# 7                  A          SNP      Missense_Mutation             N7_vs_T7
# 8                  A          SNP      Missense_Mutation           N44_vs_T44
# 9                  T          SNP      Missense_Mutation           N39_vs_T39
# 10                 T          SNP      Missense_Mutation             N7_vs_T7
# 11                 T          SNP      Missense_Mutation           N39_vs_T39
# 12                 T          SNP      Missense_Mutation           N15_vs_T15
# 13                 T          SNP      Missense_Mutation             N7_vs_T7
# 14                 C          SNP      Missense_Mutation           N39_vs_T39
#
#        dbSNP_RS           ...                   dbsnp._license  \
# 0    rs34151777           ...            https://goo.gl/Ztr5rl
# 1    rs35136134           ...            https://goo.gl/Ztr5rl
# 2   rs138488969           ...            https://goo.gl/Ztr5rl
# 3   rs111360507           ...            https://goo.gl/Ztr5rl
# 4     rs1131660           ...            https://goo.gl/Ztr5rl
# 5     rs1800282           ...            https://goo.gl/Ztr5rl
# 6   rs148071782           ...            https://goo.gl/Ztr5rl
# 7    rs77202343           ...            https://goo.gl/Ztr5rl
# 8   rs543528838           ...            https://goo.gl/Ztr5rl
# 9    rs34144478           ...            https://goo.gl/Ztr5rl
# 10   rs12722482           ...            https://goo.gl/Ztr5rl
# 11   rs41562012           ...            https://goo.gl/Ztr5rl
# 12          NaN           ...                              NaN
# 13  rs148931839           ...            https://goo.gl/Ztr5rl
# 14   rs77652527           ...            https://goo.gl/Ztr5rl
#
#     exonicfunc_knowngene              hgvs_id  \
# 0      nonsynonymous SNV  chr9:g.138377498G>T
# 1      nonsynonymous SNV  chr9:g.139405649C>T
# 2      nonsynonymous SNV  chr1:g.152280110C>T
# 3      nonsynonymous SNV  chr1:g.152281795C>T
# 4      nonsynonymous SNV  chr16:g.89838086C>A
# 5      nonsynonymous SNV  chr16:g.89883007A>T
# 6      nonsynonymous SNV   chr19:g.1036460G>A
# 7      nonsynonymous SNV  chr14:g.24803710G>A
# 8      nonsynonymous SNV  chr4:g.187627812G>A
# 9      nonsynonymous SNV   chr6:g.27834677C>T
# 10     nonsynonymous SNV   chr6:g.29797420C>T
# 11     nonsynonymous SNV   chr6:g.31238179C>T
# 12     nonsynonymous SNV  chr22:g.19230452C>T
# 13     nonsynonymous SNV   chr3:g.40503506C>T
# 14     nonsynonymous SNV  chr7:g.151949735T>C
#
#    samples.filter_passing_reads_count  samples.genotype  \
# 0                                  75              None
# 1                                 276              None
# 2                                 322              None
# 3                                 410              None
# 4                                 337              None
# 5                                  25              None
# 6                                  36              None
# 7                                 292              None
# 8                                 242              None
# 9                                 138              None
# 10                                128              None
# 11                                138              None
# 12                                368              None
# 13                                 34              None
# 14                                290              None
#
#        wellderly._license  wellderly.alleles.allele1  \
# 0   https://goo.gl/e8OO17                          T
# 1                     NaN                        NaN
# 2   https://goo.gl/e8OO17                          C
# 3   https://goo.gl/e8OO17                          C
# 4   https://goo.gl/e8OO17                          A
# 5   https://goo.gl/e8OO17                          A
# 6                     NaN                        NaN
# 7   https://goo.gl/e8OO17                          A
# 8                     NaN                        NaN
# 9   https://goo.gl/e8OO17                          C
# 10  https://goo.gl/e8OO17                          C
# 11  https://goo.gl/e8OO17                          C
# 12                    NaN                        NaN
# 13  https://goo.gl/e8OO17                          C
# 14  https://goo.gl/e8OO17                          C
#
#     wellderly.alleles.allele2  wellderly.alleles.freq1 wellderly.alleles.freq2
# 0                           G                   0.0575                  0.9425
# 1                         NaN                      NaN                     NaN
# 2                           T                   0.9800                  0.0200
# 3                           T                   0.9975                  0.0025
# 4                           C                   0.0300                  0.9700
# 5                           T                   0.9175                  0.0825
# 6                         NaN                      NaN                     NaN
# 7                           G                   0.0250                  0.9750
# 8                         NaN                      NaN                     NaN
# 9                           T                   0.9400                  0.0600
# 10                          T                   0.9125                  0.0875
# 11                          T                   0.9925                  0.0075
# 12                        NaN                      NaN                     NaN
# 13                          T                   0.9550                  0.0450
# 14                          T                   0.0325                  0.9675
#
# [15 rows x 72 columns]

# %%
df4.to_csv('rare_deleterious_variants.maf',  sep= "\t", index=False)

# %% [markdown]
# ### Format the input using subsets iteratively

# %%
txt1 = str(maf_formatter(wholeDataSet)) # using list as output instead of data frame
txt2 = str(maf_formatter_core(wholeDataSet))
txt1 == txt2

# %% [markdown]
# # Citation

# %% [markdown]
# Birmingham, A., Mark, A. M., Mazzaferro, C., Xu, G., & Fisch, K. M. (2018). Efficient population-scale variant analysis and prioritization with VAPr. Bioinformatics (Oxford, England), 34(16), 2843–2845. doi:10.1093/bioinformatics/bty192
